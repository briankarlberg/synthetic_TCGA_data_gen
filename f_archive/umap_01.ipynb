# %%
# convert real gexp to uint8 on front end
# Next: run on dense-layer VAE output

# %%
import umap
import glob as glob
import pandas as pd
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %%
all_files = sorted(glob.glob(
    '../gexp_files/*.tsv'))

# %%
raw_gexp = pd.read_csv(all_files[2],sep='\t',index_col = 0)

# %%
raw_gexp.head(2)
# Out:
#               Labels  N:GEXP::?:100130426:  N:GEXP::?:100133144:  \
# BRCA
# TCGA-3C-AAAU  BRCA_1                   0.0               16.3640
# TCGA-3C-AALI  BRCA_4                   0.0                9.2659
#
#               N:GEXP::?:100134869:  N:GEXP::?:10357:  N:GEXP::?:10431:  \
# BRCA
# TCGA-3C-AAAU                12.932            52.150            408.08
# TCGA-3C-AALI                17.379            69.755            563.89
#
#               N:GEXP::?:136542:  N:GEXP::?:155060:  N:GEXP::?:26823:  \
# BRCA
# TCGA-3C-AAAU                  0            1187.00            0.0000
# TCGA-3C-AALI                  0             516.04            1.0875
#
#               N:GEXP::?:280660:  ...  N:GEXP::ZXDA:7789:  \
# BRCA                             ...
# TCGA-3C-AAAU             0.0000  ...             129.590
# TCGA-3C-AALI             0.5438  ...              59.815
#
#               N:GEXP::ZXDB:158586:  N:GEXP::ZXDC:79364:  \
# BRCA
# TCGA-3C-AAAU               1007.80               1658.5
# TCGA-3C-AALI                448.61               1343.1
#
#               N:GEXP::ZYG11A:440590:  N:GEXP::ZYG11B:79699:  \
# BRCA
# TCGA-3C-AAAU                  258.49                1208.40
# TCGA-3C-AALI                  198.48                 603.59
#
#               N:GEXP::ZYX:7791:  N:GEXP::ZZEF1:23140:  N:GEXP::ZZZ3:26009:  \
# BRCA
# TCGA-3C-AAAU             3507.2                1894.9              1180.50
# TCGA-3C-AALI             5504.6                1318.7               406.74
#
#               N:GEXP::psiTPTE22:387590:  N:GEXP::tAKR:389932:
# BRCA
# TCGA-3C-AAAU                     1.7233                   0.0
# TCGA-3C-AALI                   926.5900                   0.0
#
# [2 rows x 20532 columns]

# %%
raw_gexp.shape
# Out:
# (995, 20532)

# %%
# iloc absolute vs named position? reset index from version 00
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 1 ]

# %%
index_pos_list # this is the index positions of BRCA_1

# %%
# import 4D latent space object from tabular converted image VAE
decoded = pd.read_csv('synth_TCGA/decoded/decoded_4D_sample_averaging.tsv',
                      sep = '\t',
                      index_col = 0)

# %%
decoded.head(2) # Extra columns are close to zero
# Out:
#     Label         0         1         2         3         4         5  \
# 0  BRCA_1  0.174624  0.138289  0.045083  0.330447  0.512801  0.049917
# 1  BRCA_1  0.217250  0.184895  0.071528  0.364796  0.505413  0.086212
#
#           6         7         8  ...    20726     20727     20728     20729  \
# 0  0.490741  0.044853  0.059693  ...  0.00081  0.000686  0.000506  0.000278
# 1  0.488446  0.082946  0.098834  ...  0.00233  0.002423  0.001724  0.000860
#
#       20730     20731     20732     20733     20734     20735
# 0  0.001446  0.000446  0.000868  0.000251  0.004089  0.000737
# 1  0.003488  0.001447  0.002842  0.000987  0.009050  0.002272
#
# [2 rows x 20737 columns]

# %%
decoded.shape
# Out:
# (10000, 20737)

# %%
# Important, keep labels for now on four synth sub components
start_col = 0

# %%
sb_typ = 'BRCA_1'

# %%
# What is this doing? subset 10k decoded samples by subtype, sample same count as real
# drops the y target Label column while somehow using it to do the subsetting
# drop the zero fill columns to complete perfect square in conv2D wrap
brca1 = decoded[decoded.Label == sb_typ].iloc[:,start_col:20532].sample(len(raw_gexp[raw_gexp.Labels == sb_typ]))
# confusing because colulmn index starts with 0 in position 1 as construction artifact

# %%
brca1
# Out:
#        Label         0         1         2         3         4         5  \
# 966   BRCA_1  0.109362  0.078788  0.017081  0.271265  0.527174  0.020054
# 140   BRCA_1  0.152085  0.119919  0.035304  0.312124  0.533742  0.041626
# 1882  BRCA_1  0.153451  0.123505  0.035039  0.319658  0.515148  0.043544
# 2372  BRCA_1  0.164994  0.129916  0.039101  0.321812  0.516148  0.049080
# 873   BRCA_1  0.118674  0.092391  0.021309  0.288804  0.533334  0.027703
# ...      ...       ...       ...       ...       ...       ...       ...
# 792   BRCA_1  0.121548  0.093841  0.021292  0.296030  0.511919  0.026419
# 1839  BRCA_1  0.163040  0.127500  0.039333  0.316575  0.533134  0.048247
# 1483  BRCA_1  0.165978  0.132333  0.042088  0.322382  0.530774  0.048980
# 1482  BRCA_1  0.241833  0.205634  0.092594  0.373687  0.517604  0.100948
# 2468  BRCA_1  0.138649  0.108627  0.028231  0.305634  0.518241  0.035537
#
#              6         7         8  ...     20521     20522     20523  \
# 966   0.508395  0.018343  0.026792  ...  0.176813  0.529041  0.489376
# 140   0.516325  0.038267  0.045779  ...  0.302473  0.536234  0.515642
# 1882  0.494356  0.040987  0.050872  ...  0.303505  0.516569  0.508786
# 2372  0.506371  0.049663  0.066055  ...  0.246874  0.507419  0.495247
# 873   0.511766  0.025984  0.031176  ...  0.325611  0.527513  0.521727
# ...        ...       ...       ...  ...       ...       ...       ...
# 792   0.477674  0.023654  0.032505  ...  0.237875  0.513723  0.494420
# 1839  0.525506  0.047794  0.060031  ...  0.271885  0.524020  0.509162
# 1483  0.514682  0.045261  0.054136  ...  0.301420  0.534398  0.513341
# 1482  0.502401  0.092652  0.105905  ...  0.330348  0.530463  0.505635
# 2468  0.499175  0.033870  0.043782  ...  0.273155  0.515896  0.505871
#
#          20524     20525     20526     20527     20528     20529     20530
# 966   0.242071  0.483899  0.552424  0.511331  0.519629  0.341785  0.000044
# 140   0.303702  0.515290  0.527347  0.514672  0.516589  0.324678  0.000251
# 1882  0.313336  0.515408  0.521235  0.533559  0.526825  0.344888  0.000267
# 2372  0.283830  0.494091  0.534107  0.538262  0.528750  0.449634  0.000446
# 873   0.276137  0.518242  0.506209  0.529861  0.524778  0.310643  0.000070
# ...        ...       ...       ...       ...       ...       ...       ...
# 792   0.291122  0.505766  0.532849  0.530302  0.528416  0.305664  0.000071
# 1839  0.280147  0.499645  0.530737  0.525885  0.521953  0.424027  0.000417
# 1483  0.314399  0.514808  0.530874  0.515045  0.516348  0.338486  0.000406
# 1482  0.384852  0.523524  0.541122  0.513732  0.512037  0.356460  0.003364
# 2468  0.287843  0.506669  0.524218  0.533533  0.527541  0.359937  0.000160
#
# [535 rows x 20532 columns]

# %%
sb_typ = 'BRCA_2'
brca2 = decoded[decoded.Label == sb_typ].iloc[:,start_col:20532].sample(len(raw_gexp[raw_gexp.Labels == sb_typ]))

# %%
sb_typ = 'BRCA_3'
brca3 = decoded[decoded.Label == sb_typ].iloc[:,start_col:20532].sample(len(raw_gexp[raw_gexp.Labels == sb_typ]))

# %%
sb_typ = 'BRCA_4'
brca4 = decoded[decoded.Label == sb_typ].iloc[:,start_col:20532].sample(len(raw_gexp[raw_gexp.Labels == sb_typ]))

# %%
# another problem, has added columns for zero-out
# it seems ok tho, recon vals here are pretty small (last couple hund cols)

# %%
del(decoded)

# %%
decoded_stack = pd.concat([brca1,
                          brca2,
                          brca3,
                          brca4])

# %%
new_lables = []
for i in decoded_stack.Label:
    if i == 'BRCA_1':
        new_lables.append('BRCA_5')
    if i == 'BRCA_2':
        new_lables.append('BRCA_6')
    if i == 'BRCA_3':
        new_lables.append('BRCA_7')
    if i == 'BRCA_4':
        new_lables.append('BRCA_8')

# %%
decoded_stack.Label = new_lables

# %%
decoded_stack.columns = raw_gexp.columns

# %%
decoded_stack.head(1) # random sampling from each subtype
# Out:
#      Labels  N:GEXP::?:100130426:  N:GEXP::?:100133144:  N:GEXP::?:100134869:  \
# 966  BRCA_5              0.109362              0.078788              0.017081
#
#      N:GEXP::?:10357:  N:GEXP::?:10431:  N:GEXP::?:136542:  N:GEXP::?:155060:  \
# 966          0.271265          0.527174           0.020054           0.508395
#
#      N:GEXP::?:26823:  N:GEXP::?:280660:  ...  N:GEXP::ZXDA:7789:  \
# 966          0.018343           0.026792  ...            0.176813
#
#      N:GEXP::ZXDB:158586:  N:GEXP::ZXDC:79364:  N:GEXP::ZYG11A:440590:  \
# 966              0.529041             0.489376                0.242071
#
#      N:GEXP::ZYG11B:79699:  N:GEXP::ZYX:7791:  N:GEXP::ZZEF1:23140:  \
# 966               0.483899           0.552424              0.511331
#
#      N:GEXP::ZZZ3:26009:  N:GEXP::psiTPTE22:387590:  N:GEXP::tAKR:389932:
# 966             0.519629                   0.341785              0.000044
#
# [1 rows x 20532 columns]

# %%
type(raw_gexp.iloc[0, 1])
# Out:
# numpy.float64

# %%
import numpy

# %%
raw_uint8 = raw_gexp.iloc[:, 1:].astype(numpy.uint8)

# %%
raw_uint8 = raw_uint8 / 255

# %%
raw_uint8.insert(0, 'Labels', raw_gexp.Labels)
# Out:
# /Users/karlberb/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3364: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#
# TCGA-XX-A899              0.513725             0.949020
# TCGA-XX-A89A              0.333333             0.372549
# TCGA-Z7-A8R5              0.972549             0.109804
# TCGA-Z7-A8R6              0.521569             0.701961
#
#               N:GEXP::ZYG11A:440590:  N:GEXP::ZYG11B:79699:  \
# BRCA
# TCGA-3C-AAAU                0.007843               0.721569
# TCGA-3C-AALI                0.776471               0.356863
# TCGA-3C-AALJ                0.294118               0.078431
# TCGA-3C-AALK                0.686275               0.372549
# TCGA-4H-AAAK                0.054902               0.027451
# ...                              ...                    ...
# TCGA-WT-AB44                0.384314               0.231373
# TCGA-XX-A899                0.082353               0.690196
# TCGA-XX-A89A                0.643137               0.917647
# TCGA-Z7-A8R5                0.200000               0.976471
# TCGA-Z7-A8R6                0.545098               0.239216
#
#               N:GEXP::ZYX:7791:  N:GEXP::ZZEF1:23140:  N:GEXP::ZZZ3:26009:  \
# BRCA
# TCGA-3C-AAAU           0.701961              0.400000             0.611765
# TCGA-3C-AALI           0.501961              0.149020             0.588235
# TCGA-3C-AALJ           0.321569              0.682353             0.992157
# TCGA-3C-AALK           0.231373              0.050980             0.737255
# TCGA-4H-AAAK           0.788235              0.247059             0.443137
# ...                         ...                   ...                  ...
# TCGA-WT-AB44           0.725490              0.125490             0.733333
# TCGA-XX-A899           0.996078              0.552941             0.619608
# TCGA-XX-A89A           0.396078              0.615686             0.725490
# TCGA-Z7-A8R5           0.074510              0.949020             0.933333
# TCGA-Z7-A8R6           0.290196              0.203922             0.807843
#
#               N:GEXP::psiTPTE22:387590:  N:GEXP::tAKR:389932:
# BRCA
# TCGA-3C-AAAU                   0.003922                   0.0
# TCGA-3C-AALI                   0.619608                   0.0
# TCGA-3C-AALJ                   0.137255                   0.0
# TCGA-3C-AALK                   0.258824                   0.0
# TCGA-4H-AAAK                   0.733333                   0.0
# ...                                 ...                   ...
# TCGA-WT-AB44                   0.831373                   0.0
# TCGA-XX-A899                   0.384314                   0.0
# TCGA-XX-A89A                   0.921569                   0.0
# TCGA-Z7-A8R5                   0.933333                   0.0
# TCGA-Z7-A8R6                   0.078431                   0.0
#
# [995 rows x 20532 columns]

# %%
# convert the labels to 5,6,7,8 for synth color mapping - done
    # future upgrade: chage naming scheme to BRCA_1_synth, etc.
# combine raw_gexp with decoded stack
# run the num_list helper function

# %%
full_stack = pd.concat([raw_uint8,
                       decoded_stack])

# %%
full_stack
# Out:
#               Labels  N:GEXP::?:100130426:  N:GEXP::?:100133144:  \
# TCGA-3C-AAAU  BRCA_1              0.000000              0.062745
# TCGA-3C-AALI  BRCA_4              0.000000              0.035294
# TCGA-3C-AALJ  BRCA_2              0.000000              0.043137
# TCGA-3C-AALK  BRCA_1              0.000000              0.047059
# TCGA-4H-AAAK  BRCA_1              0.000000              0.023529
# ...              ...                   ...                   ...
# 9948          BRCA_8              0.204596              0.171926
# 8434          BRCA_8              0.131040              0.106598
# 8200          BRCA_8              0.159626              0.132633
# 3              0.000000  ...            0.215686              0.709804
# 4              0.000000  ...            0.188235              0.658824
# ...                 ...  ...                 ...                   ...
# 1985           0.083077  ...            0.300772              0.512075
# 1986           0.032195  ...            0.239017              0.503747
# 1987           0.043425  ...            0.231132              0.519074
# 1988           0.046793  ...            0.203798              0.524053
# 1989           0.040495  ...            0.306235              0.520083
#
#       N:GEXP::ZXDC:79364:  N:GEXP::ZYG11A:440590:  N:GEXP::ZYG11B:79699:  \
# 0                0.478431                0.007843               0.721569
# 1                0.247059                0.776471               0.356863
# 2                0.000000                0.294118               0.078431
# 3                0.372549                0.686275               0.372549
# 4                0.098039                0.054902               0.027451
# ...                   ...                     ...                    ...
# 1985             0.494888                0.369215               0.519011
# 1986             0.477917                0.370284               0.524762
# 1987             0.476875                0.414113               0.524930
# 1988             0.472680                0.385897               0.510074
# 1989             0.496456                0.436848               0.546501
#
#       N:GEXP::ZYX:7791:  N:GEXP::ZZEF1:23140:  N:GEXP::ZZZ3:26009:  \
# 0              0.701961              0.400000             0.611765
# 1              0.501961              0.149020             0.588235
# 2              0.321569              0.682353             0.992157
# 3              0.231373              0.050980             0.737255
# 4              0.788235              0.247059             0.443137
# ...                 ...                   ...                  ...
# 1985           0.536614              0.530358             0.524094
# 1986           0.540370              0.531491             0.530668
# 1987           0.553277              0.521327             0.517982
# 1988           0.561962              0.520740             0.514816
# 1989           0.536387              0.515314             0.511642
#
#       N:GEXP::psiTPTE22:387590:  N:GEXP::tAKR:389932:
# 0                      0.003922              0.000000
# 1                      0.619608              0.000000
# 2                      0.137255              0.000000
# 3                      0.258824              0.000000
# 4                      0.733333              0.000000
# ...                         ...                   ...
# 1985                   0.350870              0.001240
# 1986                   0.209724              0.000082
# 1987                   0.200903              0.000228
# 1988                   0.242285              0.000255
# 1989                   0.159882              0.000230
#
# [1990 rows x 20532 columns]

# %%
n_comps = 2

# %%
reducer = umap.UMAP(n_components = n_comps)

# %%
scaled_data = StandardScaler().fit_transform(full_stack.iloc[:,1:])

# %%
embedding = reducer.fit_transform(scaled_data)
# Out:
# OMP: Info #271: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
num_list = [] 
for i in full_stack.Labels:
    num = i.split('_')[1]
    num_list.append(int(num))

# %%
fsv = 1 # Full stack version
dot_size = 35

# UMAP with 2 components, raw BRCA n = 995
# scaled_data = StandardScaler().fit_transform(raw_gexp.iloc[:,1:])

# n_comps = 2
# reducer = umap.UMAP(n_components = n_comps)
# embedding = reducer.fit_transform(scaled_data)
fig = plt.figure(figsize = (12, 12))

index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 1 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(0),
           label = 'BRCA_1')
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 2 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(2),
           label = 'BRCA_2')
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 3 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(4),
           label = 'BRCA_3')
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 4 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(6),
           label = 'BRCA_4')

index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 5 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(1),
           label = 'BRCA_1 synth')
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 6 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(3),
           label = 'BRCA_2 synth')
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 7 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(5),
           label = 'BRCA_3 synth')
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 8 ]
plt.scatter(embedding[index_pos_list,0], embedding[index_pos_list,1], s=dot_size, color=plt.cm.Paired(7),
           label = 'BRCA_4 synth')

plt.title('BRCA UMAP n_components = '+
          str(n_comps)+'\nraw gexp n = 995, uint8 decoded n = 995'
          # '\nscaler: standard, sk learn preprocessing'
         )
plt.legend(loc = 'lower right')
plt.savefig('UMAP_out/'+
            'BRCA'+'_UMAP_n_comps_'+
            str(n_comps)+'_2022-08-24_uint8_norm_'+str(fsv)+'.png')

# %%
# End, begin feed of np.float64 to image VAE

# %%
plt.cm.Paired(0)
# Out:
# (0.6509803921568628, 0.807843137254902, 0.8901960784313725, 1.0)

# %%
plt.cm.Paired(1)
# Out:
# (0.12156862745098039, 0.47058823529411764, 0.7058823529411765, 1.0)

# %%
# end v00
# try converting raw data to uint8 on the front end
# then remove unit8 on image VAE feed

# %%
fig = plt.figure()

# %%
Original v00:

# %%
type(raw_gexp.iloc[0,1])
# Out:
# numpy.float64

# %% [markdown]
# numpy.float64 is the data type of the raw gene expression values
# See histograms and heatmaps in slide deck, radically skewed with outliers

# %%
decoded.iloc[:,1:].head(2)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.174624  0.138289  0.045083  0.330447  0.512801  0.049917  0.490741
# 1  0.217250  0.184895  0.071528  0.364796  0.505413  0.086212  0.488446
#
#           7         8         9  ...    20726     20727     20728     20729  \
# 0  0.044853  0.059693  0.120348  ...  0.00081  0.000686  0.000506  0.000278
# 1  0.082946  0.098834  0.172767  ...  0.00233  0.002423  0.001724  0.000860
#
#       20730     20731     20732     20733     20734     20735
# 0  0.001446  0.000446  0.000868  0.000251  0.004089  0.000737
# 1  0.003488  0.001447  0.002842  0.000987  0.009050  0.002272
#
# [2 rows x 20736 columns]

# %%
dcdd_flt = decoded.iloc[:,1:].astype(np.float64)
dcdd_flt.head(2)
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.174624  0.138289  0.045083  0.330447  0.512801  0.049917  0.490741
# 1  0.217250  0.184895  0.071528  0.364796  0.505413  0.086212  0.488446
#
#           7         8         9  ...    20726     20727     20728     20729  \
# 0  0.044853  0.059693  0.120348  ...  0.00081  0.000686  0.000506  0.000278
# 1  0.082946  0.098834  0.172767  ...  0.00233  0.002423  0.001724  0.000860
#
#       20730     20731     20732     20733     20734     20735
# 0  0.001446  0.000446  0.000868  0.000251  0.004089  0.000737
# 1  0.003488  0.001447  0.002842  0.000987  0.009050  0.002272
#
# [2 rows x 20736 columns]

# %%
# convert raw data to uint8 - yes, this version, 01

# %%
base = np.array(gene_row + (
            20736 - len(              # dimension of nearest perfect square   
                gene_row)) * [0],
                        dtype=np.uint8)

# %%
raw_gexp.iloc[:,1:]
# Out:
#               N:GEXP::?:100130426:  N:GEXP::?:100133144:  \
# BRCA
# TCGA-3C-AAAU                0.0000               16.3640
# TCGA-3C-AALI                0.0000                9.2659
# TCGA-3C-AALJ                0.9066               11.6230
# TCGA-3C-AALK                0.0000               12.0890
# TCGA-4H-AAAK                0.0000                6.8468
# ...                            ...                   ...
# TCGA-WT-AB44                0.0000                0.0000
# TCGA-XX-A899                0.0000               14.3860
# TCGA-XX-A89A                0.0000               22.3240
# TCGA-Z7-A8R5                0.0000                2.2638
# TCGA-Z7-A8R6                0.0000                6.8865
#
#               N:GEXP::?:100134869:  N:GEXP::?:10357:  N:GEXP::?:10431:  \
# BRCA
# TCGA-3C-AAAU               12.9320            52.150            408.08
# TCGA-3C-AALI               17.3790            69.755            563.89
# TCGA-3C-AALJ                9.2294           154.300           1360.80
# TCGA-3C-AALK               11.0800           143.860            865.54
# TCGA-4H-AAAK               14.4300            84.213            766.38
# ...                            ...               ...               ...
# TCGA-WT-AB44                3.2580            42.264           1877.40
# TCGA-XX-A899               21.4410           137.780            652.76
# TCGA-XX-A89A               27.2740            64.143            722.72
# TCGA-Z7-A8R5                7.2933            85.046           1140.30
# TCGA-Z7-A8R6               24.7790           167.550           1003.60
#
#               N:GEXP::?:136542:  N:GEXP::?:155060:  N:GEXP::?:26823:  \
# BRCA
# TCGA-3C-AAAU                  0            1187.00            0.0000
# TCGA-3C-AALI                  0             516.04            1.0875
# TCGA-3C-AALJ                  0             592.02            0.0000
# TCGA-3C-AALK                  0             552.75            0.4137
# TCGA-4H-AAAK                  0             260.85            0.4255
# ...                         ...                ...               ...
# TCGA-WT-AB44                  0             704.54            4.0725
# TCGA-XX-A899                  0             427.17            2.7559
# TCGA-XX-A89A                  0             376.48            0.4724
# TCGA-Z7-A8R5                  0             252.07            0.5973
# TCGA-Z7-A8R6                  0             238.02            0.3480
#
#               N:GEXP::?:280660:  N:GEXP::?:317712:  ...  N:GEXP::ZXDA:7789:  \
# BRCA                                                ...
# TCGA-3C-AAAU             0.0000                0.0  ...             129.590
# TCGA-3C-AALI             0.5438                0.0  ...              59.815
# TCGA-3C-AALJ             0.0000                0.0  ...              35.358
# TCGA-3C-AALK             0.0000                0.0  ...              55.027
# TCGA-4H-AAAK             0.0000                0.0  ...              48.936
# ...                         ...                ...  ...                 ...
# TCGA-WT-AB44             0.0000                0.0  ...              24.435
# TCGA-XX-A899             0.0000                0.0  ...              70.866
# TCGA-XX-A89A             0.0000                0.0  ...              48.654
# TCGA-Z7-A8R5             0.0000                0.0  ...              32.255
# TCGA-Z7-A8R6             0.0000                0.0  ...              34.450
#
#               N:GEXP::ZXDB:158586:  N:GEXP::ZXDC:79364:  \
# BRCA
# TCGA-3C-AAAU               1007.80              1658.50
# TCGA-3C-AALI                448.61              1343.10
# TCGA-3C-AALJ                534.00               768.81
# TCGA-3C-AALK                437.73               863.88
# TCGA-4H-AAAK                424.25              1049.80
# ...                            ...                  ...
# TCGA-WT-AB44                243.53               772.96
# TCGA-XX-A899                643.70              1266.50
# TCGA-XX-A89A                341.52              1375.50
# TCGA-Z7-A8R5                248.48               796.23
# TCGA-Z7-A8R6                389.74               947.89
#
#               N:GEXP::ZYG11A:440590:  N:GEXP::ZYG11B:79699:  \
# BRCA
# TCGA-3C-AAAU                 258.490                1208.40
# TCGA-3C-AALI                 198.480                 603.59
# TCGA-3C-AALJ                 331.820                 532.18
# TCGA-3C-AALK                 175.420                 607.37
# TCGA-4H-AAAK                  14.043                 775.75
# ...                              ...                    ...
# TCGA-WT-AB44                  98.554                 315.21
# TCGA-XX-A899                  21.260                 688.19
# TCGA-XX-A89A                 164.380                 746.81
# TCGA-Z7-A8R5                  51.967                 505.93
# TCGA-Z7-A8R6                 139.540                 573.47
#
#               N:GEXP::ZYX:7791:  N:GEXP::ZZEF1:23140:  N:GEXP::ZZZ3:26009:  \
# BRCA
# TCGA-3C-AAAU             3507.2               1894.90              1180.50
# TCGA-3C-AALI             5504.6               1318.70               406.74
# TCGA-3C-AALJ             5458.8                942.88               509.52
# TCGA-3C-AALK             5691.4                781.13               700.87
# TCGA-4H-AAAK             4041.7                831.91               881.70
# ...                         ...                   ...                  ...
# TCGA-WT-AB44            10937.0                800.65               443.09
# TCGA-XX-A899             5118.1               1933.90               670.08
# TCGA-XX-A89A             5477.6               1437.40               953.71
# TCGA-Z7-A8R5             6675.6                754.41               750.83
# TCGA-Z7-A8R6             3402.5                564.42               462.11
#
#               N:GEXP::psiTPTE22:387590:  N:GEXP::tAKR:389932:
# BRCA
# TCGA-3C-AAAU                     1.7233                0.0000
# TCGA-3C-AALI                   926.5900                0.0000
# TCGA-3C-AALJ                    35.3580                0.0000
# TCGA-3C-AALK                    66.6120                0.0000
# TCGA-4H-AAAK                   187.2300                0.0000
# ...                                 ...                   ...
# TCGA-WT-AB44                   724.9000                0.0000
# TCGA-XX-A899                    98.4250                0.0000
# TCGA-XX-A89A                   235.2400                0.9447
# TCGA-Z7-A8R5                   238.9300                0.0000
# TCGA-Z7-A8R6                    20.8790                0.0000
#
# [995 rows x 20531 columns]

# %%
index_pos_list = [ i for i in range(len(num_list)) if num_list[i] == 1 ]

# %%
index_pos_list
# Out:
# [1,
#  2,
#  3,
#  7,
#  8,
#  9,
#  10,
#  11,
#  14,
#  15,
#  17,
#  23,
#  24,
#  25,
#  29,
#  30,
#  31,
#  32,
#  34,
#  35,
#  37,
#  39,
#  40,
#  41,
#  42,
#  43,
#  44,
#  46,
#  47,
#  48,
#  51,
#  53,
#  56,
#  59,
#  62,
#  64,
#  68,
#  72,
#  74,
#  77,
#  80,
#  81,
#  85,
#  86,
#  87,
#  89,
#  90,
#  91,
#  92,
#  94,
#  95,
#  97,
#  99,
#  103,
#  104,
#  105,
#  106,
#  109,
#  110,
#  114,
#  117,
#  118,
#  120,
#  121,
#  125,
#  126,
#  128,
#  132,
#  134,
#  135,
#  136,
#  139,
#  140,
#  141,
#  142,
#  143,
#  144,
#  145,
#  150,
#  151,
#  152,
#  153,
#  156,
#  158,
#  159,
#  160,
#  161,
#  163,
#  164,
#  165,
#  166,
#  168,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  177,
#  179,
#  182,
#  183,
#  188,
#  189,
#  192,
#  193,
#  194,
#  197,
#  199,
#  200,
#  206,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  214,
#  215,
#  216,
#  217,
#  220,
#  221,
#  222,
#  224,
#  227,
#  228,
#  229,
#  230,
#  233,
#  235,
#  238,
#  242,
#  244,
#  247,
#  249,
#  254,
#  256,
#  257,
#  259,
#  260,
#  261,
#  263,
#  264,
#  265,
#  266,
#  267,
#  269,
#  271,
#  272,
#  273,
#  279,
#  281,
#  283,
#  284,
#  285,
#  287,
#  288,
#  291,
#  292,
#  296,
#  297,
#  299,
#  300,
#  302,
#  303,
#  304,
#  306,
#  311,
#  312,
#  314,
#  316,
#  322,
#  323,
#  324,
#  325,
#  328,
#  329,
#  334,
#  338,
#  340,
#  342,
#  344,
#  345,
#  346,
#  347,
#  349,
#  350,
#  351,
#  352,
#  353,
#  357,
#  359,
#  362,
#  363,
#  366,
#  368,
#  369,
#  372,
#  375,
#  376,
#  384,
#  385,
#  388,
#  390,
#  392,
#  394,
#  395,
#  400,
#  403,
#  404,
#  406,
#  408,
#  410,
#  411,
#  412,
#  415,
#  416,
#  417,
#  418,
#  420,
#  421,
#  422,
#  425,
#  432,
#  433,
#  435,
#  436,
#  440,
#  441,
#  442,
#  443,
#  447,
#  448,
#  450,
#  451,
#  453,
#  458,
#  460,
#  462,
#  463,
#  464,
#  467,
#  468,
#  470,
#  471,
#  472,
#  473,
#  475,
#  477,
#  482,
#  483,
#  485,
#  486,
#  487,
#  488,
#  492,
#  493,
#  494,
#  495,
#  496,
#  498,
#  501,
#  503,
#  504,
#  506,
#  508,
#  511,
#  513,
#  514,
#  516,
#  517,
#  518,
#  520,
#  523,
#  525,
#  526,
#  528,
#  529,
#  531,
#  533,
#  535,
#  536,
#  537,
#  538,
#  540,
#  541,
#  542,
#  543,
#  544,
#  545,
#  549,
#  550,
#  553,
#  556,
#  557,
#  558,
#  562,
#  565,
#  568,
#  576,
#  582,
#  584,
#  585,
#  586,
#  589,
#  590,
#  591,
#  592,
#  595,
#  596,
#  597,
#  599,
#  600,
#  601,
#  606,
#  608,
#  612,
#  613,
#  614,
#  615,
#  616,
#  617,
#  620,
#  623,
#  624,
#  626,
#  627,
#  631,
#  632,
#  636,
#  637,
#  639,
#  640,
#  641,
#  643,
#  645,
#  653,
#  656,
#  659,
#  662,
#  663,
#  665,
#  666,
#  667,
#  668,
#  671,
#  673,
#  676,
#  677,
#  679,
#  682,
#  683,
#  684,
#  686,
#  687,
#  689,
#  690,
#  695,
#  698,
#  699,
#  702,
#  705,
#  706,
#  708,
#  709,
#  711,
#  712,
#  713,
#  714,
#  716,
#  722,
#  723,
#  726,
#  727,
#  730,
#  732,
#  733,
#  735,
#  736,
#  737,
#  738,
#  739,
#  740,
#  742,
#  743,
#  744,
#  745]
