# %%
# Rebuild matrices on M1 local machine
# combine code from Casey_Greene_baseline.ipynb
# and non-RNA.ipynb

# %%
import pandas as pd
from glob import glob

# %%
cv_paths = sorted(
    glob(
        '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/*CV*.tsv'))

# %%
cv_paths
# Out:
# ['/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ACC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BLCA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BRCA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/CESC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/COADREAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ESCC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/GEA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/HNSC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRCKICH_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRP_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LGGGBM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LIHCCHOL_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUSC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/MESO_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/OV_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PAAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PCPG_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PRAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SARC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SKCM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/TGCT_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THCA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THYM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UCEC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UVM_CVfolds_5FOLD_v12_20210228.tsv']

# %%
all_paths = sorted(
    glob(
        '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/*.tsv'))

# %%
all_paths
# Out:
# ['/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ACC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ACC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BLCA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BLCA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BRCA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BRCA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/CESC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/CESC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/COADREAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/COADREAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ESCC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ESCC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/GEA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/GEA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/HNSC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/HNSC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRCKICH_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRCKICH_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRP_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRP_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LGGGBM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LGGGBM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LIHCCHOL_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LIHCCHOL_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUSC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUSC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/MESO_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/MESO_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/OV_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/OV_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PAAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PAAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PCPG_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PCPG_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PRAD_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PRAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SARC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SARC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SKCM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SKCM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/TGCT_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/TGCT_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THCA_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THCA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THYM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THYM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UCEC_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UCEC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UVM_CVfolds_5FOLD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UVM_v12_20210228.tsv']

# %%
molecular_paths = list(set(all_paths) - set(cv_paths))

# %%
molecular_paths
# Out:
# ['/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/HNSC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BRCA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ACC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LIHCCHOL_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PCPG_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PRAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SARC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/CESC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SKCM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THCA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UCEC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/GEA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRP_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/TGCT_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LUSC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/THYM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/PAAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/BLCA_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/COADREAD_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/LGGGBM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRCKICH_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/MESO_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ESCC_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/UVM_v12_20210228.tsv',
#  '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/OV_v12_20210228.tsv']

# %%
# CG bl version

# %%
import os

# %%
# dataDir = "/Users/karlberb/work/tmp/v12/TMP_v12_20210228"

# %%
dataDir = '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228'

# %%
headers = {}
for a in glob(os.path.join(dataDir, "*_v12_20210228.tsv")): #
    name = os.path.basename(a).replace("_v12_20210228.tsv", "")
    if "5FOLD" not in a:
        with open(a, "rt") as handle:
            header = handle.readline()
            a = pd.Index( list(a for a in header.rstrip().split("\t") if a.startswith("N:GEXP::")) )
            headers[name] = a

# %%
isect = None
for a in headers:
    if a not in ["LGGGBM"]:
        if isect is None:
            isect = headers[a]
        else:
            isect = isect.intersection(headers[a])
isect = isect.insert(0, "Labels")

# %%
outDir = "./data"

# %%
ls
# Out:
# Casey_Greene_baseline.ipynb
# Classical ML on raw vs decoded notes.rtf
# Code_demo_2022-11-02.rtf
# RF_BRCA_r0/
# a_ntrsct_00.ipynb
# baseline_00.ipynb
# baseline_01.ipynb
# baseline_02.ipynb
# baseline_03.ipynb
# baseline_04.ipynb
# baseline_05.ipynb
# data/
# decoded/
# decoded_baseline_F1s/
# decoded_baseline_plots/
# matrices_build.ipynb
# non-RNA.ipynb
# normalizer.ipynb
# overlay.ipynb
# raw_baseline_F1s/
# raw_baseline_plots/
# umap.ipynb

# %%
pwd
# Out:
# '/Users/karlberb/Documents/work/sample_count/synthetic_TCGA_data_gen/g_devel'

# %%
ls data

# %%
for a in headers:
    if a not in ["LGGGBM"]:
        ipath = os.path.join(dataDir, a + "_v12_20210228.tsv")
        opath = os.path.join(outDir, a + ".tsv")
        x = pd.read_csv(ipath, sep="\t", index_col=0)
        x[isect].to_csv(opath, sep="\t")

# %%
# to baseline 5

# %%
a
# Out:
# 'SKCM'

# %%
name
# Out:
# 'CESC_CVfolds_5FOLD'

# %%
handle # rt is a mode of the open function
# Out:
# <_io.TextIOWrapper name='/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/SKCM_v12_20210228.tsv' mode='rt' encoding='UTF-8'>

# %%
# recycling a variable

# %%
headers_miR = {}
for a_n in glob(os.path.join(dataDir, "*_v12_20210228.tsv")): #
    # break
    name_n = os.path.basename(a_n).replace("_v12_20210228.tsv", "")
    # break
    if "5FOLD" not in a_n: # using the 'in' function to apply logic to two strings
        with open(a_n, "rt") as handle_n:
            header_n = handle_n.readline()
            a_m = pd.Index( list(a_n for a_n in header.rstrip().split("\t") if a_n.startswith("N:MIR")) )
            headers_miR[name_n] = a_m

# %%
headers_miR
# Out:
# {}

# %%
a_n
# Out:
# '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/CESC_CVfolds_5FOLD_v12_20210228.tsv'

# %%
name #fail
# Out:
# 'SKCM'

# %%
name_n # so basname gets RHS then replace strips the version and data
    # basically does what string split does
# Out:
# 'PAAD_CVfolds_5FOLD'

# %%
# mod second half with 'm' notation to prevent overwrite

# %%
headers_miR
# Out:
# {'SKCM': Index(['N:GEXP::?:100130426:', 'N:GEXP::?:100133144:', 'N:GEXP::?:100134869:',
#         'N:GEXP::?:10357:', 'N:GEXP::?:10431:', 'N:GEXP::?:136542:',
#         'N:GEXP::?:155060:', 'N:GEXP::?:26823:', 'N:GEXP::?:280660:',
#         'N:GEXP::?:317712:',
#         ...
#         'N:GEXP::ZXDA:7789:', 'N:GEXP::ZXDB:158586:', 'N:GEXP::ZXDC:79364:',
#         'N:GEXP::ZYG11A:440590:', 'N:GEXP::ZYG11B:79699:', 'N:GEXP::ZYX:7791:',
#         'N:GEXP::ZZEF1:23140:', 'N:GEXP::ZZZ3:26009:',
#         'N:GEXP::psiTPTE22:387590:', 'N:GEXP::tAKR:389932:'],
#        dtype='object', length=20531)}

# %%
len(headers_miR)
# Out:
# 26

# %%
a_m
# Out:
# Index(['N:GEXP::?:100130426:', 'N:GEXP::?:100133144:', 'N:GEXP::?:100134869:',
#        'N:GEXP::?:10357:', 'N:GEXP::?:10431:', 'N:GEXP::?:136542:',
#        'N:GEXP::?:155060:', 'N:GEXP::?:26823:', 'N:GEXP::?:280660:',
#        'N:GEXP::?:317712:',
#        ...
#        'N:GEXP::ZXDA:7789:', 'N:GEXP::ZXDB:158586:', 'N:GEXP::ZXDC:79364:',
#        'N:GEXP::ZYG11A:440590:', 'N:GEXP::ZYG11B:79699:', 'N:GEXP::ZYX:7791:',
#        'N:GEXP::ZZEF1:23140:', 'N:GEXP::ZZZ3:26009:',
#        'N:GEXP::psiTPTE22:387590:', 'N:GEXP::tAKR:389932:'],
#       dtype='object', length=20531)

# %%
isect_miR = None

# %%
isect_miR

# %%
isect_miR = None
for a_i in headers_miR:
    if a_i not in ["LGGGBM"]:
        if isect_miR is None:
            isect_miR = headers_miR[a_i]
        else:
            isect_miR = isect_miR.intersection(headers_miR[a_i])
isect_miR = isect_miR.insert(0, "Labels")

# %%
len(isect_miR)
# Out:
# 744

# %%
outDir_miR = "./data_miR"

# %%
a_w
# Out:
# 'KIRCKICH'

# %%
dataDir
# Out:
# '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228'

# %%
ipath
# Out:
# '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/KIRCKICH_v12_20210228.tsv'

# %%
opath
# Out:
# './data_miR/KIRCKICH.tsv'

# %%
x
# Out:
#                   Labels  B:MUTA:COMP:DMD::  B:MUTA:COMP:NRAS::  \
# KIRCKICH
# TCGA-3Z-A93Z  KIRCKICH_1                  0                   0
# TCGA-6D-AA2E  KIRCKICH_1                  0                   0
# TCGA-A3-3308  KIRCKICH_1                  0                   0
# TCGA-A3-3311  KIRCKICH_1                  0                   0
# TCGA-A3-3313  KIRCKICH_1                  0                   0
# ...                  ...                ...                 ...
# TCGA-MM-A563  KIRCKICH_1                  0                   0
# TCGA-MM-A564  KIRCKICH_1                  0                   0
# TCGA-MM-A84U  KIRCKICH_1                  0                   0
# TCGA-MW-A4EC  KIRCKICH_1                  0                   0
# TCGA-T7-A92I  KIRCKICH_1                  0                   0
#
#               B:MUTA:COMP:XPO1::  B:MUTA:COMP:HES3::  B:MUTA:COMP:SAV1::  \
# KIRCKICH
# TCGA-3Z-A93Z                   0                   0                   0
# TCGA-6D-AA2E                   0                   0                   0
# TCGA-A3-3308                   0                   0                   0
# TCGA-A3-3311                   0                   0                   0
# TCGA-A3-3313                   0                   0                   0
# ...                          ...                 ...                 ...
# TCGA-MM-A563                   0                   0                   0
# TCGA-MM-A564                   0                   0                   0
# TCGA-MM-A84U                   0                   0                   0
# TCGA-MW-A4EC                   0                   0                   0
# TCGA-T7-A92I                   0                   0                   0
#
#               B:MUTA:COMP:EEF1A1::  B:MUTA:COMP:DKK1::  B:MUTA:COMP:DNER::  \
# KIRCKICH
# TCGA-3Z-A93Z                     0                   0                   0
# TCGA-6D-AA2E                     0                   0                   0
# TCGA-A3-3308                     0                   0                   0
# TCGA-A3-3311                     0                   0                   0
# TCGA-A3-3313                     0                   0                   0
# ...                            ...                 ...                 ...
# TCGA-MM-A563                     0                   0                   0
# TCGA-MM-A564                     0                   0                   0
# TCGA-MM-A84U                     0                   0                   0
# TCGA-MW-A4EC                     0                   0                   0
# TCGA-T7-A92I                     0                   0                   0
#
#               B:MUTA:COMP:MAP2K4::  ...  I:CNVR::TMEM256:254863:  \
# KIRCKICH                            ...
# TCGA-3Z-A93Z                     0  ...                        0
# TCGA-6D-AA2E                     0  ...                        0
# TCGA-A3-3308                     0  ...                       -1
# TCGA-A3-3311                     0  ...                        0
# TCGA-A3-3313                     0  ...                        1
# ...                            ...  ...                      ...
# TCGA-MM-A563                     0  ...                        0
# TCGA-MM-A564                     0  ...                        0
# TCGA-MM-A84U                     0  ...                        0
# TCGA-MW-A4EC                     0  ...                        0
# TCGA-T7-A92I                     0  ...                        1
#
#               I:CNVR::PPARG:5468:  I:CNVR::ARHGEF3:50650:  \
# KIRCKICH
# TCGA-3Z-A93Z                   -1                      -1
# TCGA-6D-AA2E                    0                       0
# TCGA-A3-3308                   -1                       0
# TCGA-A3-3311                   -1                      -1
# TCGA-A3-3313                   -1                      -1
# ...                           ...                     ...
# TCGA-MM-A563                   -1                      -1
# TCGA-MM-A564                   -1                      -1
# TCGA-MM-A84U                   -1                      -1
# TCGA-MW-A4EC                   -1                      -1
# TCGA-T7-A92I                    0                       0
#
#               I:CNVR::ARHGAP19:84986:  I:CNVR::MED17:9440:  \
# KIRCKICH
# TCGA-3Z-A93Z                        0                    0
# TCGA-6D-AA2E                        0                    0
# TCGA-A3-3308                        0                    0
# TCGA-A3-3311                        0                    0
# TCGA-A3-3313                        0                    1
# ...                               ...                  ...
# TCGA-MM-A563                        0                    0
# TCGA-MM-A564                        0                    0
# TCGA-MM-A84U                        0                    0
# TCGA-MW-A4EC                        0                    0
# TCGA-T7-A92I                        0                    0
#
#               I:CNVR::MGC27345:157247:  I:CNVR::ZBTB14:7541:  \
# KIRCKICH
# TCGA-3Z-A93Z                         0                     0
# TCGA-6D-AA2E                         0                     0
# TCGA-A3-3308                         0                     1
# TCGA-A3-3311                         0                     0
# TCGA-A3-3313                         1                     0
# ...                                ...                   ...
# TCGA-MM-A563                         0                     0
# TCGA-MM-A564                         1                     0
# TCGA-MM-A84U                         0                    -1
# TCGA-MW-A4EC                         0                     0
# TCGA-T7-A92I                         0                     0
#
#               I:CNVR::ZNF474:133923:  I:CNVR::PPIF:10105:  I:CNVR::PRKG1:5592:
# KIRCKICH
# TCGA-3Z-A93Z                       1                    0                    0
# TCGA-6D-AA2E                       0                    0                    0
# TCGA-A3-3308                       0                    0                    0
# TCGA-A3-3311                       0                    0                    0
# TCGA-A3-3313                       0                    0                    0
# ...                              ...                  ...                  ...
# TCGA-MM-A563                       0                    0                    0
# TCGA-MM-A564                       1                    0                    0
# TCGA-MM-A84U                       0                    0                    0
# TCGA-MW-A4EC                       1                    0                    0
# TCGA-T7-A92I                       0                    0                    0
#
# [556 rows x 26952 columns]

# %%
# need to do real stats on these files. Drill on the incongruencies

# %%
idx = x.columns[1:]

# %%
first_two = []
for i in idx:
    plc_one_two = i.split(':')
    first_two.append(plc_one_two[0] + ':' + plc_one_two[1])

# %%
set(first_two) # End
# Out:
# {'B:MUTA', 'I:CNVR', 'N:GEXP', 'N:METH'}

# %%
for a_w in headers:
    if a_w not in ["LGGGBM"]:
        ipath = os.path.join(dataDir, a_w + "_v12_20210228.tsv")
        opath = os.path.join(outDir_miR, a_w + ".tsv")
        x = pd.read_csv(ipath, sep="\t", index_col=0)
        x[isect_miR].to_csv(opath, sep="\t")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [48], line 6
#       4 opath = os.path.join(outDir_miR, a_w + ".tsv")
#       5 x = pd.read_csv(ipath, sep="\t", index_col=0)
# ----> 6 x[isect_miR].to_csv(opath, sep="\t")
#
# File ~/miniforge3/envs/tf_M1_py3dot9/lib/python3.9/site-packages/pandas/core/frame.py:3810, in DataFrame.__getitem__(self, key)
#    3808     if is_iterator(key):
#    3809         key = list(key)
# -> 3810     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3812 # take() does not accept boolean indexers
#    3813 if getattr(indexer, "dtype", None) == bool:
#
# File ~/miniforge3/envs/tf_M1_py3dot9/lib/python3.9/site-packages/pandas/core/indexes/base.py:6111, in Index._get_indexer_strict(self, key, axis_name)
#    6108 else:
#    6109     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6111 self._raise_if_missing(keyarr, indexer, axis_name)
#    6113 keyarr = self.take(indexer)
#    6114 if isinstance(key, Index):
#    6115     # GH 42790 - Preserve name from an Index
#
# File ~/miniforge3/envs/tf_M1_py3dot9/lib/python3.9/site-packages/pandas/core/indexes/base.py:6174, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6171     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6173 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6174 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['N:MIR::hsa-let-7a-2-3p:Corrected:', 'N:MIR::hsa-let-7a-3p:Corrected:', 'N:MIR::hsa-let-7a-5p:Corrected:', 'N:MIR::hsa-let-7b-3p:Corrected:', 'N:MIR::hsa-let-7b-5p:Corrected:', 'N:MIR::hsa-let-7c-3p:Corrected:', 'N:MIR::hsa-let-7c-5p:Corrected:', 'N:MIR::hsa-let-7d-3p:Corrected:', 'N:MIR::hsa-let-7d-5p:Corrected:', 'N:MIR::hsa-let-7e-3p:Corrected:', 'N:MIR::hsa-let-7e-5p:Corrected:', 'N:MIR::hsa-let-7f-1-3p:Corrected:', 'N:MIR::hsa-let-7f-5p:Corrected:', 'N:MIR::hsa-let-7g-3p:Corrected:', 'N:MIR::hsa-let-7g-5p:Corrected:', 'N:MIR::hsa-let-7i-3p:Corrected:', 'N:MIR::hsa-let-7i-5p:Corrected:', 'N:MIR::hsa-miR-1:Corrected:', 'N:MIR::hsa-miR-100-5p:Corrected:', 'N:MIR::hsa-miR-101-3p:Corrected:', 'N:MIR::hsa-miR-101-5p:Corrected:', 'N:MIR::hsa-miR-103a-2-5p:Corrected:', 'N:MIR::hsa-miR-103a-3p:Corrected:', 'N:MIR::hsa-miR-105-3p:Corrected:', 'N:MIR::hsa-miR-105-5p:Corrected:', 'N:MIR::hsa-miR-106a-5p:Corrected:', 'N:MIR::hsa-miR-106b-3p:Corrected:', 'N:MIR::hsa-miR-106b-5p:Corrected:', 'N:MIR::hsa-miR-107:Corrected:', 'N:MIR::hsa-miR-10a-3p:Corrected:', 'N:MIR::hsa-miR-10a-5p:Corrected:', 'N:MIR::hsa-miR-10b-3p:Corrected:', 'N:MIR::hsa-miR-10b-5p:Corrected:', 'N:MIR::hsa-miR-1179:Corrected:', 'N:MIR::hsa-miR-1180-3p:Corrected:', 'N:MIR::hsa-miR-1185-1-3p:Corrected:', 'N:MIR::hsa-miR-1197:Corrected:', 'N:MIR::hsa-miR-1224-5p:Corrected:', 'N:MIR::hsa-miR-122-5p:Corrected:', 'N:MIR::hsa-miR-1226-3p:Corrected:', 'N:MIR::hsa-miR-1228-3p:Corrected:', 'N:MIR::hsa-miR-1229-3p:Corrected:', 'N:MIR::hsa-miR-124-3p:Corrected:', 'N:MIR::hsa-miR-1247