# %% [markdown]
# ### Setup, to be organized

# %%
# Format learning curves per DeepMind RL paper:
# https://arxiv.org/pdf/2205.11448.pdf

# %%
# from figure_five_v2 in the parent directory - source of quality-of-embedding plot

# %%
from IPython.display import Image

# %%
pwd
# Out:
# '/Users/karlberb/Documents/work/sample_count/synthetic_TCGA_data_gen/g_learning_curves/i_o'

# %%
ls ..
# Out:
# DAG_smpl_effct_repo.drawio           figure_five.ipynb
# DAG_smpl_effct_repo.jpg              figure_five_v2.ipynb
# PDF.ipynb                            i_o/
# augmented_policy_cloning.svg         learning_curve_schematic.drawio
# bitmap.jpg                           learning_curve_schematic.drawio.png
# c_latent_sampling.ipynb              learning_curve_schematic_v2.drawio
# data_aug_deepmind.jpg                learning_curve_schematic_v2.jpg
# data_aug_deepmind.svg                shuffle.ipynb

# %%
Image('../augmented_policy_cloning.jpg', width = 400)

# %%
import seaborn as sns

# %%
sns.color_palette("hls", 10)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.6832, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.41279999999999994, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.5167999999999995, 0.86),
#  (0.4752000000000003, 0.33999999999999997, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6207999999999999)]

# %%
sns.color_palette("husl", 10)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8616090647292522, 0.536495730113334, 0.19548899031476086),
#  (0.6804189127793346, 0.6151497514677574, 0.19405452111445337),
#  (0.46810256823426105, 0.6699492535792404, 0.1928958739904499),
#  (0.20125317221201128, 0.6907920815379025, 0.47966761189275336),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.2197995660828324, 0.6625157876850336, 0.7732093159317209),
#  (0.433280341176423, 0.6065273407962815, 0.9585467098271748),
#  (0.8004936186423958, 0.47703363533737203, 0.9579547196007522),
#  (0.962272393509669, 0.3976451968965351, 0.8008274363432775)]

# %%
sns.color_palette("hls", 8)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.7612000000000001, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5012000000000001),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.33999999999999997, 0.43879999999999986, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.6987999999999996)]

# %%
sns.color_palette("husl", 8)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8087954113106306, 0.5634700050056693, 0.19502642696727285),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.19783576093349015, 0.6955516966063037, 0.3995301037444499),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.22335772267769388, 0.6565792317435265, 0.8171355503265633),
#  (0.6423044349219739, 0.5497680051256467, 0.9582651433656727),
#  (0.9603888539940703, 0.3814317878772117, 0.8683117650835491)]

# %%
sns.color_palette("husl", 8)[5]
# Out:
# (0.22335772267769388, 0.6565792317435265, 0.8171355503265633)

# %%
sns.color_palette("hls", 3)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.3712),
#  (0.3712, 0.33999999999999997, 0.86)]

# %%
sns.color_palette("hls", 4)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.5688000000000001, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.6311999999999998, 0.33999999999999997, 0.86)]

# %%
sns.color_palette("hls", 5)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.5167999999999995, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86)]

# %%
sns.color_palette("hls", 6)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.8287999999999999, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.3712),
#  (0.33999999999999997, 0.8287999999999999, 0.86),
#  (0.3712, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.8287999999999999)]

# %%
sns.color_palette("hls", 7)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.8169142857142857, 0.33999999999999997),
#  (0.4573714285714283, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.6683428571428571),
#  (0.33999999999999997, 0.6059428571428571, 0.86),
#  (0.5197714285714281, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.7545142857142858)]

# %%
sns.color_palette("husl", 6)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.7350228985632719, 0.5952719904750953, 0.1944419133847522),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744),
#  (0.9082572436765556, 0.40195790729656516, 0.9576909250290225)]

# %%
sns.color_palette("husl", 7)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.7757319041862729, 0.5784925270759935, 0.19475566538551875),
#  (0.5105309046900421, 0.6614299289084904, 0.1930849118538962),
#  (0.20433460114757862, 0.6863857739476534, 0.5407103379425205),
#  (0.21662978923073606, 0.6676586160122123, 0.7318695594345369),
#  (0.5049017849530067, 0.5909119231215284, 0.9584657252128558),
#  (0.9587050080494409, 0.3662259565791742, 0.9231469575614251)]

# %%
sns.color_palette("hls", 15)
# Out:
# [(0.86, 0.3712, 0.33999999999999997),
#  (0.86, 0.5791999999999999, 0.33999999999999997),
#  (0.86, 0.7872, 0.33999999999999997),
#  (0.7247999999999999, 0.86, 0.33999999999999997),
#  (0.5167999999999999, 0.86, 0.33999999999999997),
#  (0.33999999999999997, 0.86, 0.3712),
#  (0.33999999999999997, 0.86, 0.5792000000000002),
#  (0.33999999999999997, 0.86, 0.7872000000000001),
#  (0.33999999999999997, 0.7247999999999999, 0.86),
#  (0.33999999999999997, 0.5167999999999999, 0.86),
#  (0.3712, 0.33999999999999997, 0.86),
#  (0.5791999999999999, 0.33999999999999997, 0.86),
#  (0.7871999999999999, 0.33999999999999997, 0.86),
#  (0.86, 0.33999999999999997, 0.7247999999999996),
#  (0.86, 0.33999999999999997, 0.5167999999999995)]

# %%
sns.color_palette("husl", 2)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681)]

# %%
sns.color_palette("husl", 3)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744)]

# %%
sns.color_palette("husl", 4)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.5920891529639701, 0.6418467016378244, 0.1935069134991043),
#  (0.21044753832183283, 0.6773105080456748, 0.6433941168468681),
#  (0.6423044349219739, 0.5497680051256467, 0.9582651433656727)]

# %%
# Ok, now get a model fit to ACC

# %%
# Probably a good time to do some de novo feature selection
# or get the big results matrix from the tmp project

# %%
sns.color_palette("husl", 4)

# %%
# compare the feature set from big results matrix with the MAD 5k feture sets

# %%
import pandas as pd

# %%
brm = pd.read_csv('/Users/karlberb/Documents/work/GDAN_TMP/big_results_matrix.tsv',
                  sep = '\t',
                  index_col = 0)
# Out:
# /var/folders/5v/88tvwqd94gs4dfr3h6rt1_w0qd13bg/T/ipykernel_61940/2728427467.py:1: DtypeWarning: Columns (15,19,30,31,32,33,34,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   brm = pd.read_csv('/Users/karlberb/Documents/work/GDAN_TMP/big_results_matrix.tsv',

# %%
brm
# Out:
#                                               cohort  \
# featureID
# CF_ACC_All_All_ACC                               ACC
# CF_ACC_All_All_ACC                               ACC
# CF_ACC_All_All_ACC                               ACC
# CF_ACC_All_All_ACC                               ACC
# CF_ACC_All_All_ACC                               ACC
# ...                                              ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
#
#                                                                                         model  \
# featureID
# CF_ACC_All_All_ACC                                   CF_ACC_All_All|CF_ACC_All_All|20210305|c
# CF_ACC_All_All_ACC                                   CF_ACC_All_All|CF_ACC_All_All|20210305|c
# CF_ACC_All_All_ACC                                   CF_ACC_All_All|CF_ACC_All_All|20210305|c
# CF_ACC_All_All_ACC                                   CF_ACC_All_All|CF_ACC_All_All|20210305|c
# CF_ACC_All_All_ACC                                   CF_ACC_All_All|CF_ACC_All_All|20210305|c
# ...                                                                                       ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf9|jadbio_LIHCCHOL_MUT...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf9|jadbio_LIHCCHOL_MUT...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf9|jadbio_LIHCCHOL_MUT...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf9|jadbio_LIHCCHOL_MUT...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf9|jadbio_LIHCCHOL_MUT...
#
#                                                                  performance_metric  \
# featureID
# CF_ACC_All_All_ACC                                                      overall_acc
# CF_ACC_All_All_ACC                                                     overall_bacc
# CF_ACC_All_All_ACC                                              overall_weighted_f1
# CF_ACC_All_All_ACC                                                overall_precision
# CF_ACC_All_All_ACC                                                   overall_recall
# ...                                                                             ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL       LIHCCHOL:5_69_samples_subtype_bacc
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL         LIHCCHOL:5_69_samples_subtype_f1
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL:5_69_samples_subtype_precision
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL     LIHCCHOL:5_69_samples_subtype_recall
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL    LIHCCHOL:5_69_samples_subtype_support
#
#                                               Mean   Median     Std  StdMed  \
# featureID
# CF_ACC_All_All_ACC                           0.701   0.6870  0.0954  0.0965
# CF_ACC_All_All_ACC                           0.672   0.6720  0.1030  0.1030
# CF_ACC_All_All_ACC                           0.689   0.6760  0.1010  0.1020
# CF_ACC_All_All_ACC                           0.714   0.7250  0.1150  0.1160
# CF_ACC_All_All_ACC                           0.701   0.6870  0.0954  0.0965
# ...                                            ...      ...     ...     ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL   0.533   0.5350  0.0300  0.0301
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL   0.148   0.1420  0.1210  0.1210
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL   0.490   0.2770  0.4470  0.4950
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL   0.157   0.0769  0.2110  0.2260
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  13.800  14.0000  0.3990  0.4470
#
#                                                 SEM  Count        Max  ...  \
# featureID                                                              ...
# CF_ACC_All_All_ACC                          0.01900     25   0.875000  ...
# CF_ACC_All_All_ACC                          0.02060     25   0.833333  ...
# CF_ACC_All_All_ACC                          0.02030     25   0.861979  ...
# CF_ACC_All_All_ACC                          0.02310     25   0.902778  ...
# CF_ACC_All_All_ACC                          0.01900     25   0.875000  ...
# ...                                             ...    ...        ...  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  0.00776     15   0.573733  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  0.03120     15   0.333333  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  0.11500     15   1.000000  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  0.05470     15   0.714286  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  0.10300     15  14.000000  ...
#
#                                             subtypes_defined_by_Histology  \
# featureID
# CF_ACC_All_All_ACC                                                    NaN
# CF_ACC_All_All_ACC                                                    NaN
# CF_ACC_All_All_ACC                                                    NaN
# CF_ACC_All_All_ACC                                                    NaN
# CF_ACC_All_All_ACC                                                    NaN
# ...                                                                   ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            0.0
#
#                                             subtypes_defined_by_iCluster  \
# featureID
# CF_ACC_All_All_ACC                                                   NaN
# CF_ACC_All_All_ACC                                                   NaN
# CF_ACC_All_All_ACC                                                   NaN
# CF_ACC_All_All_ACC                                                   NaN
# CF_ACC_All_All_ACC                                                   NaN
# ...                                                                  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           0.0
#
#                                            subtypes_defined_by_COCA  \
# featureID
# CF_ACC_All_All_ACC                                              NaN
# CF_ACC_All_All_ACC                                              NaN
# CF_ACC_All_All_ACC                                              NaN
# CF_ACC_All_All_ACC                                              NaN
# CF_ACC_All_All_ACC                                              NaN
# ...                                                             ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      0.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      0.0
#
#                                            subtypes_defined_by_Other  \
# featureID
# CF_ACC_All_All_ACC                                               NaN
# CF_ACC_All_All_ACC                                               NaN
# CF_ACC_All_All_ACC                                               NaN
# CF_ACC_All_All_ACC                                               NaN
# CF_ACC_All_All_ACC                                               NaN
# ...                                                              ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       1.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       1.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       1.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       1.0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       1.0
#
#                                            total_features GEXP_features  \
# featureID
# CF_ACC_All_All_ACC                            __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                            __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                            __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                            __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                            __NO_LIST__   __NO_LIST__
# ...                                                   ...           ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
#
#                                            CNVR_features METH_features  \
# featureID
# CF_ACC_All_All_ACC                           __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                           __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                           __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                           __NO_LIST__   __NO_LIST__
# CF_ACC_All_All_ACC                           __NO_LIST__   __NO_LIST__
# ...                                                  ...           ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
#
#                                            MIR_features  MUTA_features
# featureID
# CF_ACC_All_All_ACC                          __NO_LIST__    __NO_LIST__
# CF_ACC_All_All_ACC                          __NO_LIST__    __NO_LIST__
# CF_ACC_All_All_ACC                          __NO_LIST__    __NO_LIST__
# CF_ACC_All_All_ACC                          __NO_LIST__    __NO_LIST__
# CF_ACC_All_All_ACC                          __NO_LIST__    __NO_LIST__
# ...                                                 ...            ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
#
# [14808849 rows x 35 columns]

# %%
14,808,849

# %%
owf1 = brm[brm.performance_metric == 'overall_weighted_f1']

# %%
owf1
# Out:
#                                               cohort  \
# featureID
# CF_ACC_All_All_ACC                               ACC
# CF_ACC_All_Top_1000_ACC                          ACC
# CF_ACC_All_Top_100_ACC                           ACC
# CF_ACC_All_Top_10_ACC                            ACC
# CF_ACC_All_Top_1_ACC                             ACC
# ...                                              ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  LIHCCHOL
#
#                                                                                         model  \
# featureID
# CF_ACC_All_All_ACC                                   CF_ACC_All_All|CF_ACC_All_All|20210305|c
# CF_ACC_All_Top_1000_ACC                     CF_ACC_All_Top_1000|CF_ACC_All_Top_1000|202103...
# CF_ACC_All_Top_100_ACC                       CF_ACC_All_Top_100|CF_ACC_All_Top_100|20210305|c
# CF_ACC_All_Top_10_ACC                          CF_ACC_All_Top_10|CF_ACC_All_Top_10|20210305|c
# CF_ACC_All_Top_1_ACC                             CF_ACC_All_Top_1|CF_ACC_All_Top_1|20210305|c
# ...                                                                                       ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf997|jadbio_LIHCCHOL_M...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf998|jadbio_LIHCCHOL_M...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf999|jadbio_LIHCCHOL_M...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf99|jadbio_LIHCCHOL_MU...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  jadbio_LIHCCHOL_MUTA_conf9|jadbio_LIHCCHOL_MUT...
#
#                                              performance_metric   Mean  \
# featureID
# CF_ACC_All_All_ACC                          overall_weighted_f1  0.689
# CF_ACC_All_Top_1000_ACC                     overall_weighted_f1  0.693
# CF_ACC_All_Top_100_ACC                      overall_weighted_f1  0.697
# CF_ACC_All_Top_10_ACC                       overall_weighted_f1  0.664
# CF_ACC_All_Top_1_ACC                        overall_weighted_f1  0.477
# ...                                                         ...    ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  overall_weighted_f1  0.260
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  overall_weighted_f1  0.260
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL  overall_weighted_f1  0.260
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  overall_weighted_f1  0.248
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL  overall_weighted_f1  0.283
#
#                                             Median     Std  StdMed     SEM  \
# featureID
# CF_ACC_All_All_ACC                           0.676  0.1010  0.1020  0.0203
# CF_ACC_All_Top_1000_ACC                      0.674  0.1060  0.1080  0.0212
# CF_ACC_All_Top_100_ACC                       0.705  0.0972  0.0976  0.0194
# CF_ACC_All_Top_10_ACC                        0.633  0.0770  0.0829  0.0154
# CF_ACC_All_Top_1_ACC                         0.500  0.1220  0.1240  0.0244
# ...                                            ...     ...     ...     ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL   0.261  0.0607  0.0607  0.0156
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL   0.261  0.0607  0.0607  0.0156
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL   0.261  0.0607  0.0607  0.0156
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL   0.258  0.0667  0.0673  0.0172
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL   0.286  0.0758  0.0759  0.0195
#
#                                             Count       Max  ...  \
# featureID                                                    ...
# CF_ACC_All_All_ACC                             25  0.861979  ...
# CF_ACC_All_Top_1000_ACC                        25  0.919658  ...
# CF_ACC_All_Top_100_ACC                         25  0.846931  ...
# CF_ACC_All_Top_10_ACC                          25  0.824179  ...
# CF_ACC_All_Top_1_ACC                           25  0.686092  ...
# ...                                           ...       ...  ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL     15  0.356374  ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL     15  0.356374  ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL     15  0.356374  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL     15  0.395401  ...
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL     15  0.425485  ...
#
#                                             subtypes_defined_by_Histology  \
# featureID
# CF_ACC_All_All_ACC                                                    NaN
# CF_ACC_All_Top_1000_ACC                                               NaN
# CF_ACC_All_Top_100_ACC                                                NaN
# CF_ACC_All_Top_10_ACC                                                 NaN
# CF_ACC_All_Top_1_ACC                                                  NaN
# ...                                                                   ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                            NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                            NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                            NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                            NaN
#
#                                             subtypes_defined_by_iCluster  \
# featureID
# CF_ACC_All_All_ACC                                                   NaN
# CF_ACC_All_Top_1000_ACC                                              NaN
# CF_ACC_All_Top_100_ACC                                               NaN
# CF_ACC_All_Top_10_ACC                                                NaN
# CF_ACC_All_Top_1_ACC                                                 NaN
# ...                                                                  ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                           NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                           NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                           NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                           NaN
#
#                                            subtypes_defined_by_COCA  \
# featureID
# CF_ACC_All_All_ACC                                              NaN
# CF_ACC_All_Top_1000_ACC                                         NaN
# CF_ACC_All_Top_100_ACC                                          NaN
# CF_ACC_All_Top_10_ACC                                           NaN
# CF_ACC_All_Top_1_ACC                                            NaN
# ...                                                             ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                      NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                      NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                      NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                      NaN
#
#                                            subtypes_defined_by_Other  \
# featureID
# CF_ACC_All_All_ACC                                               NaN
# CF_ACC_All_Top_1000_ACC                                          NaN
# CF_ACC_All_Top_100_ACC                                           NaN
# CF_ACC_All_Top_10_ACC                                            NaN
# CF_ACC_All_Top_1_ACC                                             NaN
# ...                                                              ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                       NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                       NaN
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL                       NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       NaN
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL                       NaN
#
#                                            total_features GEXP_features  \
# featureID
# CF_ACC_All_All_ACC                            __NO_LIST__   __NO_LIST__
# CF_ACC_All_Top_1000_ACC                       __NO_LIST__   __NO_LIST__
# CF_ACC_All_Top_100_ACC                                100            70
# CF_ACC_All_Top_10_ACC                                  10             6
# CF_ACC_All_Top_1_ACC                                    1             1
# ...                                                   ...           ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL             11             0
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL             11             0
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL             11             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             14             0
#
#                                            CNVR_features METH_features  \
# featureID
# CF_ACC_All_All_ACC                           __NO_LIST__   __NO_LIST__
# CF_ACC_All_Top_1000_ACC                      __NO_LIST__   __NO_LIST__
# CF_ACC_All_Top_100_ACC                                 0            26
# CF_ACC_All_Top_10_ACC                                  0             3
# CF_ACC_All_Top_1_ACC                                   0             0
# ...                                                  ...           ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL             0             0
#
#                                            MIR_features  MUTA_features
# featureID
# CF_ACC_All_All_ACC                          __NO_LIST__    __NO_LIST__
# CF_ACC_All_Top_1000_ACC                     __NO_LIST__    __NO_LIST__
# CF_ACC_All_Top_100_ACC                                4              0
# CF_ACC_All_Top_10_ACC                                 1              0
# CF_ACC_All_Top_1_ACC                                  0              0
# ...                                                 ...            ...
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL            0             11
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL            0             11
# jadbio_LIHCCHOL_MUTA_feature_set5_LIHCCHOL            0             11
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
# jadbio_LIHCCHOL_MUTA_feature_set1_LIHCCHOL            0             14
#
# [412585 rows x 35 columns]

# %%
412,585

# %%
del(brm)

# %%
acc_owf1 = owf1[owf1.cohort == 'ACC']

# %%
acc_owf1
# Out:
#                                  cohort  \
# featureID
# CF_ACC_All_All_ACC                  ACC
# CF_ACC_All_Top_1000_ACC             ACC
# CF_ACC_All_Top_100_ACC              ACC
# CF_ACC_All_Top_10_ACC               ACC
# CF_ACC_All_Top_1_ACC                ACC
# ...                                 ...
# jadbio_ACC_GEXP_feature_set5_ACC    ACC
# jadbio_ACC_GEXP_feature_set5_ACC    ACC
# jadbio_ACC_GEXP_feature_set5_ACC    ACC
# jadbio_ACC_GEXP_feature_set1_ACC    ACC
# jadbio_ACC_GEXP_feature_set1_ACC    ACC
#
#                                                                               model  \
# featureID
# CF_ACC_All_All_ACC                         CF_ACC_All_All|CF_ACC_All_All|20210305|c
# CF_ACC_All_Top_1000_ACC           CF_ACC_All_Top_1000|CF_ACC_All_Top_1000|202103...
# CF_ACC_All_Top_100_ACC             CF_ACC_All_Top_100|CF_ACC_All_Top_100|20210305|c
# CF_ACC_All_Top_10_ACC                CF_ACC_All_Top_10|CF_ACC_All_Top_10|20210305|c
# CF_ACC_All_Top_1_ACC                   CF_ACC_All_Top_1|CF_ACC_All_Top_1|20210305|c
# ...                                                                             ...
# jadbio_ACC_GEXP_feature_set5_ACC  jadbio_ACC_GEXP_conf997|jadbio_ACC_GEXP_featur...
# jadbio_ACC_GEXP_feature_set5_ACC  jadbio_ACC_GEXP_conf998|jadbio_ACC_GEXP_featur...
# jadbio_ACC_GEXP_feature_set5_ACC  jadbio_ACC_GEXP_conf999|jadbio_ACC_GEXP_featur...
# jadbio_ACC_GEXP_feature_set1_ACC  jadbio_ACC_GEXP_conf99|jadbio_ACC_GEXP_feature...
# jadbio_ACC_GEXP_feature_set1_ACC  jadbio_ACC_GEXP_conf9|jadbio_ACC_GEXP_feature_...
#
#                                    performance_metric   Mean  Median     Std  \
# featureID
# CF_ACC_All_All_ACC                overall_weighted_f1  0.689   0.676  0.1010
# CF_ACC_All_Top_1000_ACC           overall_weighted_f1  0.693   0.674  0.1060
# CF_ACC_All_Top_100_ACC            overall_weighted_f1  0.697   0.705  0.0972
# CF_ACC_All_Top_10_ACC             overall_weighted_f1  0.664   0.633  0.0770
# CF_ACC_All_Top_1_ACC              overall_weighted_f1  0.477   0.500  0.1220
# ...                                               ...    ...     ...     ...
# jadbio_ACC_GEXP_feature_set5_ACC  overall_weighted_f1  0.263   0.266  0.0201
# jadbio_ACC_GEXP_feature_set5_ACC  overall_weighted_f1  0.263   0.266  0.0201
# jadbio_ACC_GEXP_feature_set5_ACC  overall_weighted_f1  0.263   0.266  0.0201
# jadbio_ACC_GEXP_feature_set1_ACC  overall_weighted_f1  0.589   0.570  0.1200
# jadbio_ACC_GEXP_feature_set1_ACC  overall_weighted_f1  0.265   0.266  0.0266
#
#                                   StdMed      SEM  Count       Max  ...  \
# featureID                                                           ...
# CF_ACC_All_All_ACC                0.1020  0.02030     25  0.861979  ...
# CF_ACC_All_Top_1000_ACC           0.1080  0.02120     25  0.919658  ...
# CF_ACC_All_Top_100_ACC            0.0976  0.01940     25  0.846931  ...
# CF_ACC_All_Top_10_ACC             0.0829  0.01540     25  0.824179  ...
# CF_ACC_All_Top_1_ACC              0.1240  0.02440     25  0.686092  ...
# ...                                  ...      ...    ...       ...  ...
# jadbio_ACC_GEXP_feature_set5_ACC  0.0202  0.00318     40  0.291498  ...
# jadbio_ACC_GEXP_feature_set5_ACC  0.0202  0.00318     40  0.291498  ...
# jadbio_ACC_GEXP_feature_set5_ACC  0.0202  0.00318     40  0.291498  ...
# jadbio_ACC_GEXP_feature_set1_ACC  0.1210  0.01900     40  0.807630  ...
# jadbio_ACC_GEXP_feature_set1_ACC  0.0266  0.00421     40  0.378409  ...
#
#                                   subtypes_defined_by_Histology  \
# featureID
# CF_ACC_All_All_ACC                                          NaN
# CF_ACC_All_Top_1000_ACC                                     NaN
# CF_ACC_All_Top_100_ACC                                      NaN
# CF_ACC_All_Top_10_ACC                                       NaN
# CF_ACC_All_Top_1_ACC                                        NaN
# ...                                                         ...
# jadbio_ACC_GEXP_feature_set5_ACC                            NaN
# jadbio_ACC_GEXP_feature_set5_ACC                            NaN
# jadbio_ACC_GEXP_feature_set5_ACC                            NaN
# jadbio_ACC_GEXP_feature_set1_ACC                            NaN
# jadbio_ACC_GEXP_feature_set1_ACC                            NaN
#
#                                   subtypes_defined_by_iCluster  \
# featureID
# CF_ACC_All_All_ACC                                         NaN
# CF_ACC_All_Top_1000_ACC                                    NaN
# CF_ACC_All_Top_100_ACC                                     NaN
# CF_ACC_All_Top_10_ACC                                      NaN
# CF_ACC_All_Top_1_ACC                                       NaN
# ...                                                        ...
# jadbio_ACC_GEXP_feature_set5_ACC                           NaN
# jadbio_ACC_GEXP_feature_set5_ACC                           NaN
# jadbio_ACC_GEXP_feature_set5_ACC                           NaN
# jadbio_ACC_GEXP_feature_set1_ACC                           NaN
# jadbio_ACC_GEXP_feature_set1_ACC                           NaN
#
#                                  subtypes_defined_by_COCA  \
# featureID
# CF_ACC_All_All_ACC                                    NaN
# CF_ACC_All_Top_1000_ACC                               NaN
# CF_ACC_All_Top_100_ACC                                NaN
# CF_ACC_All_Top_10_ACC                                 NaN
# CF_ACC_All_Top_1_ACC                                  NaN
# ...                                                   ...
# jadbio_ACC_GEXP_feature_set5_ACC                      NaN
# jadbio_ACC_GEXP_feature_set5_ACC                      NaN
# jadbio_ACC_GEXP_feature_set5_ACC                      NaN
# jadbio_ACC_GEXP_feature_set1_ACC                      NaN
# jadbio_ACC_GEXP_feature_set1_ACC                      NaN
#
#                                  subtypes_defined_by_Other total_features  \
# featureID
# CF_ACC_All_All_ACC                                     NaN    __NO_LIST__
# CF_ACC_All_Top_1000_ACC                                NaN    __NO_LIST__
# CF_ACC_All_Top_100_ACC                                 NaN            100
# CF_ACC_All_Top_10_ACC                                  NaN             10
# CF_ACC_All_Top_1_ACC                                   NaN              1
# ...                                                    ...            ...
# jadbio_ACC_GEXP_feature_set5_ACC                       NaN             10
# jadbio_ACC_GEXP_feature_set5_ACC                       NaN             10
# jadbio_ACC_GEXP_feature_set5_ACC                       NaN             10
# jadbio_ACC_GEXP_feature_set1_ACC                       NaN             11
# jadbio_ACC_GEXP_feature_set1_ACC                       NaN             11
#
#                                  GEXP_features CNVR_features METH_features  \
# featureID
# CF_ACC_All_All_ACC                 __NO_LIST__   __NO_LIST__   __NO_LIST__
# CF_ACC_All_Top_1000_ACC            __NO_LIST__   __NO_LIST__   __NO_LIST__
# CF_ACC_All_Top_100_ACC                      70             0            26
# CF_ACC_All_Top_10_ACC                        6             0             3
# CF_ACC_All_Top_1_ACC                         1             0             0
# ...                                        ...           ...           ...
# jadbio_ACC_GEXP_feature_set5_ACC            10             0             0
# jadbio_ACC_GEXP_feature_set5_ACC            10             0             0
# jadbio_ACC_GEXP_feature_set5_ACC            10             0             0
# jadbio_ACC_GEXP_feature_set1_ACC            11             0             0
# jadbio_ACC_GEXP_feature_set1_ACC            11             0             0
#
#                                  MIR_features  MUTA_features
# featureID
# CF_ACC_All_All_ACC                __NO_LIST__    __NO_LIST__
# CF_ACC_All_Top_1000_ACC           __NO_LIST__    __NO_LIST__
# CF_ACC_All_Top_100_ACC                      4              0
# CF_ACC_All_Top_10_ACC                       1              0
# CF_ACC_All_Top_1_ACC                        0              0
# ...                                       ...            ...
# jadbio_ACC_GEXP_feature_set5_ACC            0              0
# jadbio_ACC_GEXP_feature_set5_ACC            0              0
# jadbio_ACC_GEXP_feature_set5_ACC            0              0
# jadbio_ACC_GEXP_feature_set1_ACC            0              0
# jadbio_ACC_GEXP_feature_set1_ACC            0              0
#
# [24525 rows x 35 columns]

# %%
24,525

# %%
acc_owf1.sort_values('Mean', ascending = False)
# Out:
#                                                    cohort  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC          ACC
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...    ACC
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC          ACC
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC          ACC
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC          ACC
# ...                                                   ...
# jadbio_ACC_MUTA_feature_set13_ACC                     ACC
# jadbio_ACC_MUTA_feature_set11_ACC                     ACC
# jadbio_ACC_MUTA_feature_set11_ACC                     ACC
# jadbio_ACC_MUTA_feature_set11_ACC                     ACC
# jadbio_ACC_MUTA_feature_set13_ACC                     ACC
#
#                                                                                                 model  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC        jadbio_ACC_GEXP_conf2088|jadbio_ACC_GEXP_cumul...
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...  jadbio_ACC_MULTIDATATYPE_conf2880|jadbio_ACC_M...
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC        jadbio_ACC_GEXP_conf2088|jadbio_ACC_GEXP_cumul...
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC        jadbio_ACC_GEXP_conf2088|jadbio_ACC_GEXP_cumul...
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC        jadbio_ACC_GEXP_conf2088|jadbio_ACC_GEXP_cumul...
# ...                                                                                               ...
# jadbio_ACC_MUTA_feature_set13_ACC                   jadbio_ACC_MUTA_conf3001|jadbio_ACC_MUTA_featu...
# jadbio_ACC_MUTA_feature_set11_ACC                   jadbio_ACC_MUTA_conf2537|jadbio_ACC_MUTA_featu...
# jadbio_ACC_MUTA_feature_set11_ACC                   jadbio_ACC_MUTA_conf2540|jadbio_ACC_MUTA_featu...
# jadbio_ACC_MUTA_feature_set11_ACC                   jadbio_ACC_MUTA_conf2546|jadbio_ACC_MUTA_featu...
# jadbio_ACC_MUTA_feature_set13_ACC                   jadbio_ACC_MUTA_conf3004|jadbio_ACC_MUTA_featu...
#
#                                                      performance_metric  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC        overall_weighted_f1
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...  overall_weighted_f1
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC        overall_weighted_f1
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC        overall_weighted_f1
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC        overall_weighted_f1
# ...                                                                 ...
# jadbio_ACC_MUTA_feature_set13_ACC                   overall_weighted_f1
# jadbio_ACC_MUTA_feature_set11_ACC                   overall_weighted_f1
# jadbio_ACC_MUTA_feature_set11_ACC                   overall_weighted_f1
# jadbio_ACC_MUTA_feature_set11_ACC                   overall_weighted_f1
# jadbio_ACC_MUTA_feature_set13_ACC                   overall_weighted_f1
#
#                                                      Mean  Median     Std  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC        0.973   1.000  0.0357
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...  0.973   1.000  0.0483
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC        0.973   1.000  0.0364
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC        0.972   1.000  0.0382
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC        0.971   1.000  0.0357
# ...                                                   ...     ...     ...
# jadbio_ACC_MUTA_feature_set13_ACC                   0.126   0.125  0.0298
# jadbio_ACC_MUTA_feature_set11_ACC                   0.126   0.115  0.0645
# jadbio_ACC_MUTA_feature_set11_ACC                   0.126   0.115  0.0645
# jadbio_ACC_MUTA_feature_set11_ACC                   0.125   0.115  0.0645
# jadbio_ACC_MUTA_feature_set13_ACC                   0.125   0.125  0.0323
#
#                                                     StdMed      SEM  Count  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC        0.0445  0.00565     40
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...  0.0548  0.00966     25
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC        0.0453  0.00575     40
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC        0.0469  0.00604     40
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC        0.0455  0.00565     40
# ...                                                    ...      ...    ...
# jadbio_ACC_MUTA_feature_set13_ACC                   0.0298  0.00544     30
# jadbio_ACC_MUTA_feature_set11_ACC                   0.0654  0.01170     30
# jadbio_ACC_MUTA_feature_set11_ACC                   0.0654  0.01170     30
# jadbio_ACC_MUTA_feature_set11_ACC                   0.0653  0.01170     30
# jadbio_ACC_MUTA_feature_set13_ACC                   0.0323  0.00591     30
#
#                                                          Max  ...  \
# featureID                                                     ...
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC        1.000000  ...
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...  1.000000  ...
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC        1.000000  ...
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC        1.000000  ...
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC        1.000000  ...
# ...                                                      ...  ...
# jadbio_ACC_MUTA_feature_set13_ACC                   0.186982  ...
# jadbio_ACC_MUTA_feature_set11_ACC                   0.266304  ...
# jadbio_ACC_MUTA_feature_set11_ACC                   0.266304  ...
# jadbio_ACC_MUTA_feature_set11_ACC                   0.266304  ...
# jadbio_ACC_MUTA_feature_set13_ACC                   0.186982  ...
#
#                                                     subtypes_defined_by_Histology  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                                  NaN
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...                            NaN
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                                  NaN
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                                  NaN
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                                  NaN
# ...                                                                           ...
# jadbio_ACC_MUTA_feature_set13_ACC                                             NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                             NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                             NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                             NaN
# jadbio_ACC_MUTA_feature_set13_ACC                                             NaN
#
#                                                     subtypes_defined_by_iCluster  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                                 NaN
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...                           NaN
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                                 NaN
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                                 NaN
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                                 NaN
# ...                                                                          ...
# jadbio_ACC_MUTA_feature_set13_ACC                                            NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                            NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                            NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                            NaN
# jadbio_ACC_MUTA_feature_set13_ACC                                            NaN
#
#                                                    subtypes_defined_by_COCA  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                            NaN
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...                      NaN
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                            NaN
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                            NaN
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                            NaN
# ...                                                                     ...
# jadbio_ACC_MUTA_feature_set13_ACC                                       NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                       NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                       NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                       NaN
# jadbio_ACC_MUTA_feature_set13_ACC                                       NaN
#
#                                                    subtypes_defined_by_Other  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                             NaN
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...                       NaN
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                             NaN
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                             NaN
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                             NaN
# ...                                                                      ...
# jadbio_ACC_MUTA_feature_set13_ACC                                        NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                        NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                        NaN
# jadbio_ACC_MUTA_feature_set11_ACC                                        NaN
# jadbio_ACC_MUTA_feature_set13_ACC                                        NaN
#
#                                                    total_features  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                   20
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...             23
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                   18
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                   17
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                   23
# ...                                                           ...
# jadbio_ACC_MUTA_feature_set13_ACC                               3
# jadbio_ACC_MUTA_feature_set11_ACC                               3
# jadbio_ACC_MUTA_feature_set11_ACC                               3
# jadbio_ACC_MUTA_feature_set11_ACC                               3
# jadbio_ACC_MUTA_feature_set13_ACC                               3
#
#                                                    GEXP_features  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                  20
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...            11
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                  18
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                  17
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                  23
# ...                                                          ...
# jadbio_ACC_MUTA_feature_set13_ACC                              0
# jadbio_ACC_MUTA_feature_set11_ACC                              0
# jadbio_ACC_MUTA_feature_set11_ACC                              0
# jadbio_ACC_MUTA_feature_set11_ACC                              0
# jadbio_ACC_MUTA_feature_set13_ACC                              0
#
#                                                    CNVR_features  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                   0
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...             0
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                   0
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                   0
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                   0
# ...                                                          ...
# jadbio_ACC_MUTA_feature_set13_ACC                              0
# jadbio_ACC_MUTA_feature_set11_ACC                              0
# jadbio_ACC_MUTA_feature_set11_ACC                              0
# jadbio_ACC_MUTA_feature_set11_ACC                              0
# jadbio_ACC_MUTA_feature_set13_ACC                              0
#
#                                                    METH_features MIR_features  \
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                   0            0
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...             9            3
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                   0            0
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                   0            0
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                   0            0
# ...                                                          ...          ...
# jadbio_ACC_MUTA_feature_set13_ACC                              0            0
# jadbio_ACC_MUTA_feature_set11_ACC                              0            0
# jadbio_ACC_MUTA_feature_set11_ACC                              0            0
# jadbio_ACC_MUTA_feature_set11_ACC                              0            0
# jadbio_ACC_MUTA_feature_set13_ACC                              0            0
#
#                                                     MUTA_features
# featureID
# jadbio_ACC_GEXP_cumulative_feature_set20_ACC                    0
# jadbio_ACC_MULTIDATATYPE_cumulative_feature_set...              0
# jadbio_ACC_GEXP_cumulative_feature_set18_ACC                    0
# jadbio_ACC_GEXP_cumulative_feature_set17_ACC                    0
# jadbio_ACC_GEXP_cumulative_feature_set23_ACC                    0
# ...                                                           ...
# jadbio_ACC_MUTA_feature_set13_ACC                               3
# jadbio_ACC_MUTA_feature_set11_ACC                               3
# jadbio_ACC_MUTA_feature_set11_ACC                               3
# jadbio_ACC_MUTA_feature_set11_ACC                               3
# jadbio_ACC_MUTA_feature_set13_ACC                               3
#
# [24525 rows x 35 columns]

# %%
acc_owf1.columns
# Out:
# Index(['cohort', 'model', 'performance_metric', 'Mean', 'Median', 'Std',
#        'StdMed', 'SEM', 'Count', 'Max', 'Min', 'Sum', 'feature_list_method',
#        'feature_list_cohort', 'feature_list_size', 'subtypeID', 'subtype_size',
#        'TMP_name', 'Cluster_name', 'size_in_marker_paper',
#        'subtypes_defined_by_mRNA', 'subtypes_defined_by_CN',
#        'subtypes_defined_by_Mutations', 'subtypes_defined_by_Meth',
#        'subtypes_defined_by_miRNA', 'subtypes_defined_by_Histology',
#        'subtypes_defined_by_iCluster', 'subtypes_defined_by_COCA',
#        'subtypes_defined_by_Other', 'total_features', 'GEXP_features',
#        'CNVR_features', 'METH_features', 'MIR_features', 'MUTA_features'],
#       dtype='object')

# %%
acc_owf1.feature_list_cohort
# Out:
# featureID
# CF_ACC_All_All_ACC                  __NONE__
# CF_ACC_All_Top_1000_ACC             __NONE__
# CF_ACC_All_Top_100_ACC                   ACC
# CF_ACC_All_Top_10_ACC                    ACC
# CF_ACC_All_Top_1_ACC                     ACC
#                                       ...
# jadbio_ACC_GEXP_feature_set5_ACC         ACC
# jadbio_ACC_GEXP_feature_set5_ACC         ACC
# jadbio_ACC_GEXP_feature_set5_ACC         ACC
# jadbio_ACC_GEXP_feature_set1_ACC         ACC
# jadbio_ACC_GEXP_feature_set1_ACC         ACC
# Name: feature_list_cohort, Length: 24525, dtype: object

# %%
https://arxiv.org/pdf/2204.09810.pdf

# %%
# The envisioned figure here is one cancer with multiple feature sets
# across multiple training regimes
# Should probably repeat to get macro-error across training runs

# %%
acc_owf1_sk = acc_owf1[acc_owf1.model.str.contains('skgrid')]

# %%
acc_owf1_sk.sort_values('Mean', ascending = False)
# Out:
#                                         cohort  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# ...                                        ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
#
#                                                                                      model  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_ExtraTrees(criterion=gini,n_estimators=...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_ExtraTrees(criterion=entropy,n_estimato...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  skgrid_LogisticRegression(C=0.01,max_iter=500,...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_LogisticRegression(C=0.01,max_iter=500,...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_ExtraTrees(criterion=entropy,n_estimato...
# ...                                                                                    ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_KNeighbors(algorithm=ball_tree,leaf_siz...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_KNeighbors(algorithm=kd_tree,leaf_size=...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_KNeighbors(algorithm=kd_tree,leaf_size=...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_KNeighbors(algorithm=kd_tree,leaf_size=...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_KNeighbors(algorithm=brute,leaf_size=15...
#
#                                           performance_metric   Mean  Median  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.879   0.899
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.869   0.862
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  overall_weighted_f1  0.864   0.853
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.864   0.863
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.864   0.864
# ...                                                      ...    ...     ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.140   0.125
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.140   0.125
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.140   0.125
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.140   0.125
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.140   0.125
#
#                                             Std  StdMed     SEM  Count  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0753  0.0779  0.0168     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0825  0.0827  0.0184     20
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  0.0680  0.0689  0.0152     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0782  0.0782  0.0174     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0645  0.0645  0.0144     20
# ...                                         ...     ...     ...    ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0640  0.0658  0.0143     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0640  0.0658  0.0143     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0640  0.0658  0.0143     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0640  0.0658  0.0143     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0640  0.0658  0.0143     20
#
#                                               Max  ...  \
# featureID                                          ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.000000  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.000000  ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  1.000000  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.000000  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.000000  ...
# ...                                           ...  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.383333  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.383333  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.383333  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.383333  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.383333  ...
#
#                                          subtypes_defined_by_Histology  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# ...                                                                ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
#
#                                          subtypes_defined_by_iCluster  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# ...                                                               ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
#
#                                         subtypes_defined_by_COCA  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# ...                                                          ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
#
#                                         subtypes_defined_by_Other  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# ...                                                           ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
#
#                                         total_features GEXP_features  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC              5             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# ...                                                ...           ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
#
#                                         CNVR_features METH_features  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# ...                                               ...           ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
#
#                                         MIR_features  MUTA_features
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC            0              0
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# ...                                              ...            ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
#
# [6209 rows x 35 columns]

# %%
acc_owf1_sk_rf = acc_owf1_sk[acc_owf1_sk.model.str.contains('RandomForest')]

# %%
acc_owf1_sk_rf.sort_values('Mean', ascending = False)
# Out:
#                                         cohort  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# skgrid_ACC_fbedeBIC_perplatformALL_ACC     ACC
# ...                                        ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
#
#                                                                                      model  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_RandomForest(criterion=gini,n_estimator...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_RandomForest(criterion=entropy,n_estima...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_RandomForest(criterion=entropy,n_estima...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_RandomForest(criterion=gini,n_estimator...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   skgrid_RandomForest(criterion=entropy,n_estima...
# ...                                                                                    ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_RandomForest(criterion=gini,n_estimator...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_RandomForest(criterion=entropy,n_estima...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_RandomForest(criterion=gini,n_estimator...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_RandomForest(criterion=gini,n_estimator...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_RandomForest(criterion=gini,n_estimator...
#
#                                           performance_metric   Mean  Median  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.858   0.861
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.851   0.861
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.851   0.860
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.845   0.863
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   overall_weighted_f1  0.844   0.854
# ...                                                      ...    ...     ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.540   0.553
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.540   0.553
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.540   0.553
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.540   0.553
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.540   0.553
#
#                                             Std  StdMed     SEM  Count  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0794  0.0795  0.0177     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0761  0.0768  0.0170     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0862  0.0866  0.0192     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0812  0.0831  0.0181     20
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.0761  0.0768  0.0170     20
# ...                                         ...     ...     ...    ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0663  0.0676  0.0148     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0663  0.0676  0.0148     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0663  0.0676  0.0148     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0663  0.0676  0.0148     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0663  0.0676  0.0148     20
#
#                                              Max  ...  \
# featureID                                         ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.00000  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.00000  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.00000  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   0.93750  ...
# skgrid_ACC_fbedeBIC_perplatformALL_ACC   1.00000  ...
# ...                                          ...  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.60989  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.60989  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.60989  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.60989  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.60989  ...
#
#                                          subtypes_defined_by_Histology  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                             NaN
# ...                                                                ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
#
#                                          subtypes_defined_by_iCluster  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                            NaN
# ...                                                               ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
#
#                                         subtypes_defined_by_COCA  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                       NaN
# ...                                                          ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
#
#                                         subtypes_defined_by_Other  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# skgrid_ACC_fbedeBIC_perplatformALL_ACC                        NaN
# ...                                                           ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
#
#                                         total_features GEXP_features  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              28             5
# ...                                                ...           ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
#
#                                         CNVR_features METH_features  \
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# skgrid_ACC_fbedeBIC_perplatformALL_ACC              9             8
# ...                                               ...           ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
#
#                                         MIR_features  MUTA_features
# featureID
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# skgrid_ACC_fbedeBIC_perplatformALL_ACC             4              2
# ...                                              ...            ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
#
# [151 rows x 35 columns]

# %%
# DT
acc_owf1_sk[acc_owf1_sk.model.str.contains('DecisionTree')].sort_values('Mean', ascending = False)
# Out:
#                                         cohort  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC           ACC
# skgrid_ACC_fbedeBIC_combined_ACC           ACC
# skgrid_ACC_fbedeBIC_combined_ACC           ACC
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC     ACC
# skgrid_ACC_fbedeBIC_combined_ACC           ACC
# ...                                        ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC    ACC
# skgrid_ACC_rfe15_perplatformCNVR_ACC       ACC
# skgrid_ACC_rfe15_perplatformCNVR_ACC       ACC
#
#                                                                                      model  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC         skgrid_DecisionTree(criterion=gini,max_depth=2...
# skgrid_ACC_fbedeBIC_combined_ACC         skgrid_DecisionTree(criterion=gini,max_depth=2...
# skgrid_ACC_fbedeBIC_combined_ACC         skgrid_DecisionTree(criterion=gini,max_depth=7...
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC   skgrid_DecisionTree(criterion=gini,max_depth=3...
# skgrid_ACC_fbedeBIC_combined_ACC         skgrid_DecisionTree(criterion=gini,max_depth=5...
# ...                                                                                    ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  skgrid_DecisionTree(criterion=gini,max_depth=1...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_DecisionTree(criterion=entropy,max_dept...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  skgrid_DecisionTree(criterion=entropy,max_dept...
# skgrid_ACC_rfe15_perplatformCNVR_ACC     skgrid_DecisionTree(criterion=gini,max_depth=2...
# skgrid_ACC_rfe15_perplatformCNVR_ACC     skgrid_DecisionTree(criterion=gini,max_depth=2...
#
#                                           performance_metric   Mean  Median  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC         overall_weighted_f1  0.750   0.778
# skgrid_ACC_fbedeBIC_combined_ACC         overall_weighted_f1  0.750   0.778
# skgrid_ACC_fbedeBIC_combined_ACC         overall_weighted_f1  0.742   0.745
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC   overall_weighted_f1  0.733   0.706
# skgrid_ACC_fbedeBIC_combined_ACC         overall_weighted_f1  0.732   0.745
# ...                                                      ...    ...     ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  overall_weighted_f1  0.489   0.487
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.474   0.477
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  overall_weighted_f1  0.474   0.477
# skgrid_ACC_rfe15_perplatformCNVR_ACC     overall_weighted_f1  0.472   0.505
# skgrid_ACC_rfe15_perplatformCNVR_ACC     overall_weighted_f1  0.470   0.505
#
#                                             Std  StdMed     SEM  Count  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC         0.1110  0.1150  0.0249     20
# skgrid_ACC_fbedeBIC_combined_ACC         0.1110  0.1150  0.0249     20
# skgrid_ACC_fbedeBIC_combined_ACC         0.1200  0.1200  0.0269     20
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC   0.0847  0.0888  0.0189     20
# skgrid_ACC_fbedeBIC_combined_ACC         0.1070  0.1080  0.0240     20
# ...                                         ...     ...     ...    ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  0.0522  0.0522  0.0116     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0748  0.0748  0.0167     20
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.0748  0.0748  0.0167     20
# skgrid_ACC_rfe15_perplatformCNVR_ACC     0.0878  0.0936  0.0196     20
# skgrid_ACC_rfe15_perplatformCNVR_ACC     0.0896  0.0960  0.0200     20
#
#                                               Max  ...  \
# featureID                                          ...
# skgrid_ACC_fbedeBIC_combined_ACC         0.873611  ...
# skgrid_ACC_fbedeBIC_combined_ACC         0.873611  ...
# skgrid_ACC_fbedeBIC_combined_ACC         0.935119  ...
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC   0.875000  ...
# skgrid_ACC_fbedeBIC_combined_ACC         0.935119  ...
# ...                                           ...  ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC  0.563492  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.590278  ...
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC  0.590278  ...
# skgrid_ACC_rfe15_perplatformCNVR_ACC     0.619780  ...
# skgrid_ACC_rfe15_perplatformCNVR_ACC     0.619780  ...
#
#                                          subtypes_defined_by_Histology  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                                   NaN
# skgrid_ACC_fbedeBIC_combined_ACC                                   NaN
# skgrid_ACC_fbedeBIC_combined_ACC                                   NaN
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC                             NaN
# skgrid_ACC_fbedeBIC_combined_ACC                                   NaN
# ...                                                                ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                            NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                               NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                               NaN
#
#                                          subtypes_defined_by_iCluster  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                                  NaN
# skgrid_ACC_fbedeBIC_combined_ACC                                  NaN
# skgrid_ACC_fbedeBIC_combined_ACC                                  NaN
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC                            NaN
# skgrid_ACC_fbedeBIC_combined_ACC                                  NaN
# ...                                                               ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                           NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                              NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                              NaN
#
#                                         subtypes_defined_by_COCA  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                             NaN
# skgrid_ACC_fbedeBIC_combined_ACC                             NaN
# skgrid_ACC_fbedeBIC_combined_ACC                             NaN
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC                       NaN
# skgrid_ACC_fbedeBIC_combined_ACC                             NaN
# ...                                                          ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                      NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                         NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                         NaN
#
#                                         subtypes_defined_by_Other  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                              NaN
# skgrid_ACC_fbedeBIC_combined_ACC                              NaN
# skgrid_ACC_fbedeBIC_combined_ACC                              NaN
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC                        NaN
# skgrid_ACC_fbedeBIC_combined_ACC                              NaN
# ...                                                           ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC                       NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                          NaN
# skgrid_ACC_rfe15_perplatformCNVR_ACC                          NaN
#
#                                         total_features GEXP_features  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                     5             3
# skgrid_ACC_fbedeBIC_combined_ACC                     5             3
# skgrid_ACC_fbedeBIC_combined_ACC                     5             3
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC               4             0
# skgrid_ACC_fbedeBIC_combined_ACC                     5             3
# ...                                                ...           ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC              5             5
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC              2             0
# skgrid_ACC_rfe15_perplatformCNVR_ACC                15             0
# skgrid_ACC_rfe15_perplatformCNVR_ACC                15             0
#
#                                         CNVR_features METH_features  \
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                    0             1
# skgrid_ACC_fbedeBIC_combined_ACC                    0             1
# skgrid_ACC_fbedeBIC_combined_ACC                    0             1
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC              0             0
# skgrid_ACC_fbedeBIC_combined_ACC                    0             1
# ...                                               ...           ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC             0             0
# skgrid_ACC_rfe15_perplatformCNVR_ACC               15             0
# skgrid_ACC_rfe15_perplatformCNVR_ACC               15             0
#
#                                         MIR_features  MUTA_features
# featureID
# skgrid_ACC_fbedeBIC_combined_ACC                   1              0
# skgrid_ACC_fbedeBIC_combined_ACC                   1              0
# skgrid_ACC_fbedeBIC_combined_ACC                   1              0
# skgrid_ACC_fbedeBIC_perplatformMIR_ACC             4              0
# skgrid_ACC_fbedeBIC_combined_ACC                   1              0
# ...                                              ...            ...
# skgrid_ACC_fbedeBIC_perplatformGEXP_ACC            0              0
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_fbedeBIC_perplatformMUTA_ACC            0              2
# skgrid_ACC_rfe15_perplatformCNVR_ACC               0              0
# skgrid_ACC_rfe15_perplatformCNVR_ACC               0              0
#
# [416 rows x 35 columns]

# %%
m_lst = []
for m in acc_owf1_sk.sort_values('Mean', ascending = False).model:
    m_lst.append(m.split('(')[0])
set(m_lst)
# Out:
# {'skgrid_AdaBoost',
#  'skgrid_BernoulliNB',
#  'skgrid_DecisionTree',
#  'skgrid_ExtraTrees',
#  'skgrid_GaussianNB',
#  'skgrid_GaussianProcess',
#  'skgrid_KNeighbors',
#  'skgrid_LogisticRegression',
#  'skgrid_PassiveAggressive',
#  'skgrid_RandomForest',
#  'skgrid_SGD',
#  'skgrid_SVC'}

# %%
res_list = []
for item in m_lst: 
    if item not in res_list: 
        res_list.append(item)
res_list
# Out:
# ['skgrid_ExtraTrees',
#  'skgrid_LogisticRegression',
#  'skgrid_RandomForest',
#  'skgrid_GaussianNB',
#  'skgrid_SGD',
#  'skgrid_SVC',
#  'skgrid_PassiveAggressive',
#  'skgrid_AdaBoost',
#  'skgrid_GaussianProcess',
#  'skgrid_KNeighbors',
#  'skgrid_DecisionTree',
#  'skgrid_BernoulliNB']

# %%
# Summary of ACC big results matrix
    # Best overall: JADBio, .97
    # Best SkGrid: ET, .88
    # Best SkGrid RF: .86
    # Best SkGrid DT: .75
    
    
# Question: Best models by miR, METH, GEXP?

# %%
# Proceed with running MAD, then plug-in new feature set
    # Run a box-and-whisker plot
        # Run Extra Trees

# %%
# Working from figure_five_v2

# %%
# Already have pandas, seaborn, and Image display

# %%
import pandas as pd
import glob as glob
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import f1_score
from statistics import mean
from statistics import stdev
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import BatchNormalization, Activation, Layer
from tensorflow.keras import metrics, optimizers
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import Callback
import tensorflow.compat.v1.keras.backend as K
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
# Again, goal is to run MAD 5k then plug-in a brm feature set
    # Box-and-whisker
    # husl and hsl color palletes

# %% [markdown]
# ### Imports

# %%
import seaborn as sns

import pandas as pd
import glob as glob
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import f1_score
from statistics import mean
from statistics import stdev
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import time
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
from tensorflow.keras.layers import BatchNormalization, Activation, Layer
from tensorflow.keras import metrics, optimizers
from tensorflow.keras.losses import binary_crossentropy
from tensorflow.keras.callbacks import Callback
import tensorflow.compat.v1.keras.backend as K
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %% [markdown]
# ### Dialed-in clf F1 box plot

# %% [markdown]
# #### Produce GEXP file set

# %%
all_paths = sorted(glob.glob('/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/*.tsv'))
cv_folds = (
    glob.glob(
        '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/*CVfolds_5FOLD*.tsv'))

# %%
df = pd.read_csv(
    '/Users/karlberb/Documents/work/GDAN_TMP/TMP_v12_20210228/ACC_v12_20210228.tsv',
    sep="\t", index_col=0)
col_ndx = df.columns[1:]
first_two = []
for i in col_ndx:
    plc_one_two = i.split(':')
    first_two.append(plc_one_two[0] + ':' + plc_one_two[1])
datatype_prefixes = list(set(first_two))

# %%
['B:MUTA', 'N:METH', 'N:GEXP', 'I:CNVR', 'N:MIR']

# %%
# GEXP production, run in figure_five_v2
for pth in molecular_files:
    file = pd.read_csv(pth,
        sep="\t", index_col=0)
    col_ndx = file.columns[1:]
    dtyp_list = [i for i in col_ndx if i.startswith(datatype_prefixes[2])]
    print(file.index.name, len(dtyp_list))
    dtyp_list = ['Labels'] + dtyp_list
    file = file.loc[:, dtyp_list]
    file.to_csv('i_o/GEXP/' +
                file.index.name + '_GEXP.tsv', sep = '\t')

# %%
# for g_path in sorted(glob.glob('i_o/GEXP/*.tsv')): # for box_whisk_v2
for g_path in sorted(glob.glob('GEXP/*.tsv')):    
    print(g_path)
    g_file = pd.read_csv(g_path, sep ='\t', index_col = 0)
    break
# Out:
# GEXP/ACC_GEXP.tsv

# %%
pwd
# Out:
# '/Users/karlberb/Documents/work/sample_count/synthetic_TCGA_data_gen/g_learning_curves/i_o'

# %%
ls
# Out:
# ACC_archive/                  dim10/
# GEXP/                         dim100_run0/
# GEXP_MAD_5k_across/           figure_five/
# GEXP_MAD_5k_across_no_LGGGBM/ latent feature inspect/
# GEXP_MAD_5k_within/           latent_feature_objects/
# GEXP_intersection/            learning_curves/
# GEXP_intersection_no_LGGGBM/  loss_plots/
# PDF_out/                      ops_notes.txt
# box_and_whiskers.ipynb        shuffle/
# decoded/                      standard_deviation_plots/

# %%
mkdir GEXP_MAD_5k_across

# %%
mkdir GEXP_intersection_no_LGGGBM

# %%
mkdir GEXP_MAD_5k_across_no_LGGGBM

# %%
# the across features should come from the intersection folder
# the within fetures should come from the GEXP folder

# %%
# GEXP feature engineering summary:
# six folders, three feature sets,
26 + 26 + 25
# Out:
# 77

# %%
ls ..
# Out:
# DAG_smpl_effct_repo.drawio           figure_five.ipynb
# DAG_smpl_effct_repo.jpg              figure_five_v2.ipynb
# PDF.ipynb                            i_o/
# augmented_policy_cloning.jpg         learning_curve_schematic.drawio
# augmented_policy_cloning.svg         learning_curve_schematic.drawio.png
# c_latent_sampling.ipynb              learning_curve_schematic_v2.drawio
# data_aug_deepmind.jpg                learning_curve_schematic_v2.jpg
# data_aug_deepmind.svg                shuffle.ipynb

# %%
g_path
# Out:
# 'GEXP/ACC_GEXP.tsv'

# %%
g_file
# Out:
#              Labels  N:GEXP::?:100130426:  N:GEXP::?:100133144:  \
# ACC
# TCGA-OR-A5J1  ACC_2                0.0000                3.2661
# TCGA-OR-A5J2  ACC_2                0.0000                2.6815
# TCGA-OR-A5J3  ACC_3                0.0000                1.7301
# TCGA-OR-A5J5  ACC_3                0.0000                0.0000
# TCGA-OR-A5J6  ACC_1                0.0000                0.0000
# ...             ...                   ...                   ...
# TCGA-OU-A5PI  ACC_3                0.0000                1.3341
# TCGA-PA-A5YG  ACC_1                0.0000                5.4184
# TCGA-PK-A5H9  ACC_1                0.3489               12.3000
# TCGA-PK-A5HA  ACC_1                0.0000                0.0000
# TCGA-PK-A5HB  ACC_2                0.0000               10.8780
#
#               N:GEXP::?:100134869:  N:GEXP::?:10357:  N:GEXP::?:10431:  \
# ACC
# TCGA-OR-A5J1                3.9385           149.130           2034.10
# TCGA-OR-A5J2                8.9948            81.078           1304.90
# TCGA-OR-A5J3                6.5650            86.488           1054.70
# TCGA-OR-A5J5                1.5492            53.912           2350.90
# TCGA-OR-A5J6                4.4709            66.906           1258.00
# ...                            ...               ...               ...
# TCGA-OU-A5PI                4.3672           114.170           2065.60
# TCGA-PA-A5YG                5.6773            90.439            779.93
# TCGA-PK-A5H9               17.3600            67.396            832.94
# TCGA-PK-A5HA                3.3076            62.988            882.58
# TCGA-PK-A5HB                4.3585            92.566           1487.20
#
#               N:GEXP::?:136542:  N:GEXP::?:155060:  N:GEXP::?:26823:  \
# ACC
# TCGA-OR-A5J1                  0            274.250            1.4409
# TCGA-OR-A5J2                  0            199.300            0.0000
# TCGA-OR-A5J3                  0            348.390            0.5925
# TCGA-OR-A5J5                  0            439.190            0.7746
# TCGA-OR-A5J6                  0            149.220            0.0000
# ...                         ...                ...               ...
# TCGA-OU-A5PI                  0            103.760            0.5701
# TCGA-PA-A5YG                  0             66.112            0.0000
# TCGA-PK-A5H9                  0            184.590            0.6979
# TCGA-PK-A5HA                  0            208.930            0.5513
# TCGA-PK-A5HB                  0             60.144            0.0000
#
#               N:GEXP::?:280660:  ...  N:GEXP::ZXDA:7789:  \
# ACC                              ...
# TCGA-OR-A5J1                0.0  ...              20.653
# TCGA-OR-A5J2                0.0  ...              57.173
# TCGA-OR-A5J3                0.0  ...              39.698
# TCGA-OR-A5J5                0.0  ...              17.816
# TCGA-OR-A5J6                0.0  ...              12.854
# ...                         ...  ...                 ...
# TCGA-OU-A5PI                0.0  ...              63.854
# TCGA-PA-A5YG                0.0  ...              67.961
# TCGA-PK-A5H9                0.0  ...              64.207
# TCGA-PK-A5HA                0.0  ...              61.742
# TCGA-PK-A5HB                0.0  ...              37.691
#
#               N:GEXP::ZXDB:158586:  N:GEXP::ZXDC:79364:  \
# ACC
# TCGA-OR-A5J1                351.58              1050.90
# TCGA-OR-A5J2                279.02              2979.90
# TCGA-OR-A5J3                495.33               914.83
# TCGA-OR-A5J5                206.04               890.78
# TCGA-OR-A5J6                117.92               894.73
# ...                            ...                  ...
# TCGA-OU-A5PI                491.45              1570.10
# TCGA-PA-A5YG                427.19               622.28
# TCGA-PK-A5H9                258.92              1022.80
# TCGA-PK-A5HA                377.07              1238.20
# TCGA-PK-A5HB                261.43               841.62
#
#               N:GEXP::ZYG11A:440590:  N:GEXP::ZYG11B:79699:  \
# ACC
# TCGA-OR-A5J1                  0.4803                 648.41
# TCGA-OR-A5J2                 31.4050                1166.00
# TCGA-OR-A5J3                  0.5925                 806.40
# TCGA-OR-A5J5                 11.6190                 553.83
# TCGA-OR-A5J6                  7.8240                 795.81
# ...                              ...                    ...
# TCGA-OU-A5PI                  0.5701                 885.40
# TCGA-PA-A5YG                  0.0000                1383.30
# TCGA-PK-A5H9                  4.1874                1613.90
# TCGA-PK-A5HA                  0.0000                 906.28
# TCGA-PK-A5HB                  8.0192                1317.60
#
#               N:GEXP::ZYX:7791:  N:GEXP::ZZEF1:23140:  N:GEXP::ZZZ3:26009:  \
# ACC
# TCGA-OR-A5J1            1841.00               1157.50               596.06
# TCGA-OR-A5J2            3060.00               1896.00               801.64
# TCGA-OR-A5J3            2655.60               1482.50               437.27
# TCGA-OR-A5J5            2367.90               1140.20               512.78
# TCGA-OR-A5J6             708.07                796.37               475.59
# ...                         ...                   ...                  ...
# TCGA-OU-A5PI            2773.10               1317.00               547.89
# TCGA-PA-A5YG            2948.20                741.56               514.10
# TCGA-PK-A5H9            1422.70               1604.10               786.53
# TCGA-PK-A5HA            2910.70                658.21               326.35
# TCGA-PK-A5HB            2812.30                731.76               615.88
#
#               N:GEXP::psiTPTE22:387590:  N:GEXP::tAKR:389932:
# ACC
# TCGA-OR-A5J1                   715.6600                0.9606
# TCGA-OR-A5J2                   581.8000                0.4026
# TCGA-OR-A5J3                   126.8000                0.0000
# TCGA-OR-A5J5                   855.1500                0.0000
# TCGA-OR-A5J6                   288.3700                0.0000
# ...                                 ...                   ...
# TCGA-OU-A5PI                   304.4500                0.0000
# TCGA-PA-A5YG                     5.5479                0.0000
# TCGA-PK-A5H9                    12.9110                0.0000
# TCGA-PK-A5HA                   371.5600                0.0000
# TCGA-PK-A5HB                  1224.1000                0.0000
#
# [76 rows x 20532 columns]

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %% [markdown]
# #### GEXP_intersection

# %%
# gexp_cols = [] # Get intersection of GEXP across TCGA
feat_lists = {}

lol_inline = []
for gexp_path in sorted(glob.glob('GEXP/*.tsv')):
    print(gexp_path)
    gexp_file = pd.read_csv(gexp_path, sep = '\t', index_col = 0)
    # feat_lists[gexp_file.index.name] = gexp_file.columns[1:]
    
    lol_inline.append(gexp_file.columns[1:])
    
intrsct = set.intersection(*map(set,lol_inline))
    
# lol = []
# for i in feat_lists:
#     print(i)
#     lol.append(list(feat_lists[i]))    
    
    
    # cols_n = list(gexp_file.columns[1:])
    # gexp_cols = gexp_cols + list(gexp_file.columns[1:])
# Out:
# GEXP/ACC_GEXP.tsv
# GEXP/BLCA_GEXP.tsv
# GEXP/BRCA_GEXP.tsv
# GEXP/CESC_GEXP.tsv
# GEXP/COADREAD_GEXP.tsv
# GEXP/ESCC_GEXP.tsv
# GEXP/GEA_GEXP.tsv
# GEXP/HNSC_GEXP.tsv
# GEXP/KIRCKICH_GEXP.tsv
# GEXP/KIRP_GEXP.tsv
# GEXP/LGGGBM_GEXP.tsv
# GEXP/LIHCCHOL_GEXP.tsv
# GEXP/LUAD_GEXP.tsv
# GEXP/LUSC_GEXP.tsv
# GEXP/MESO_GEXP.tsv
# GEXP/OV_GEXP.tsv
# GEXP/PAAD_GEXP.tsv
# GEXP/PCPG_GEXP.tsv
# GEXP/PRAD_GEXP.tsv
# GEXP/SARC_GEXP.tsv
# GEXP/SKCM_GEXP.tsv
# GEXP/TGCT_GEXP.tsv
# GEXP/THCA_GEXP.tsv
# GEXP/THYM_GEXP.tsv
# GEXP/UCEC_GEXP.tsv
# GEXP/UVM_GEXP.tsv

# %%
len(intrsct)
# Out:
# 12339

# %%
ntrsct_list = list(intrsct) # Convert intersection dict to list

# %%
lbld_ntrsct_list = ['Labels'] + ntrsct_list # Add labels column to intersection list for extraction

# %%
ls # GEXP_intersection/ is the target here
# Out:
# ACC_archive/                  dim10/
# GEXP/                         dim100_run0/
# GEXP_MAD_5k_across/           figure_five/
# GEXP_MAD_5k_across_no_LGGGBM/ latent feature inspect/
# GEXP_MAD_5k_within/           latent_feature_objects/
# GEXP_intersection/            learning_curves/
# GEXP_intersection_no_LGGGBM/  loss_plots/
# PDF_out/                      ops_notes.txt
# box_and_whiskers.ipynb        shuffle/
# decoded/                      standard_deviation_plots/

# %%
gexp_file.index.name
# Out:
# 'ACC'

# %%
# Write across-TCGA intersection files
for gexp_path in sorted(glob.glob('GEXP/*.tsv')):
    print(gexp_path)
    gexp_file = pd.read_csv(gexp_path, sep = '\t', index_col = 0)
    intrsct_gexp_file = gexp_file.loc[:, lbld_ntrsct_list]
    intrsct_gexp_file.to_csv('GEXP_intersection/' +
                gexp_file.index.name + '_GEXP_intrsct.tsv', sep = '\t')    
    # break
# Out:
# GEXP/ACC_GEXP.tsv
# GEXP/BLCA_GEXP.tsv
# GEXP/BRCA_GEXP.tsv
# GEXP/CESC_GEXP.tsv
# GEXP/COADREAD_GEXP.tsv
# GEXP/ESCC_GEXP.tsv
# GEXP/GEA_GEXP.tsv
# GEXP/HNSC_GEXP.tsv
# GEXP/KIRCKICH_GEXP.tsv
# GEXP/KIRP_GEXP.tsv
# GEXP/LGGGBM_GEXP.tsv
# GEXP/LIHCCHOL_GEXP.tsv
# GEXP/LUAD_GEXP.tsv
# GEXP/LUSC_GEXP.tsv
# GEXP/MESO_GEXP.tsv
# GEXP/OV_GEXP.tsv
# GEXP/PAAD_GEXP.tsv
# GEXP/PCPG_GEXP.tsv
# GEXP/PRAD_GEXP.tsv
# GEXP/SARC_GEXP.tsv
# GEXP/SKCM_GEXP.tsv
# GEXP/TGCT_GEXP.tsv
# GEXP/THCA_GEXP.tsv
# GEXP/THYM_GEXP.tsv
# GEXP/UCEC_GEXP.tsv
# GEXP/UVM_GEXP.tsv

# %%
# Check fail , no label cell

# %%
ls GEXP_intersection/
# Out:
# ACC_GEXP_intrsct.tsv       LUSC_GEXP_intrsct.tsv
# BLCA_GEXP_intrsct.tsv      MESO_GEXP_intrsct.tsv
# BRCA_GEXP_intrsct.tsv      OV_GEXP_intrsct.tsv
# CESC_GEXP_intrsct.tsv      PAAD_GEXP_intrsct.tsv
# COADREAD_GEXP_intrsct.tsv  PCPG_GEXP_intrsct.tsv
# ESCC_GEXP_intrsct.tsv      PRAD_GEXP_intrsct.tsv
# GEA_GEXP_intrsct.tsv       SARC_GEXP_intrsct.tsv
# HNSC_GEXP_intrsct.tsv      SKCM_GEXP_intrsct.tsv
# KIRCKICH_GEXP_intrsct.tsv  TGCT_GEXP_intrsct.tsv
# KIRP_GEXP_intrsct.tsv      THCA_GEXP_intrsct.tsv
# LGGGBM_GEXP_intrsct.tsv    THYM_GEXP_intrsct.tsv
# LIHCCHOL_GEXP_intrsct.tsv  UCEC_GEXP_intrsct.tsv
# LUAD_GEXP_intrsct.tsv      UVM_GEXP_intrsct.tsv

# %%
check_file = pd.read_csv('GEXP_intersection/LGGGBM_GEXP_intrsct.tsv',
                         sep = '\t',
                         index_col = 0)

# %%
check_file
# Out:
#                 Labels  N:GEXP::C6orf170:221322:  N:GEXP::MTHFD2:10797:  \
# LGGGBM
# TCGA-02-0001  LGGGBM_2                    2.8894                 3.7227
# TCGA-02-0003  LGGGBM_2                    3.0052                 5.1018
# TCGA-02-0006  LGGGBM_2                    3.2584                 4.8395
# TCGA-02-0007  LGGGBM_4                    2.8602                 2.9948
# TCGA-02-0009  LGGGBM_4                    4.2309                 5.3483
# ...                ...                       ...                    ...
# TCGA-TQ-A7RS  LGGGBM_3                    4.0390                 6.0606
# TCGA-TQ-A7RU  LGGGBM_3                    4.7699                 4.2443
# TCGA-TQ-A7RV  LGGGBM_1                    4.3538                 6.2102
# TCGA-TQ-A7RW  LGGGBM_1                    4.3418                 6.4841
# TCGA-VW-A7QS  LGGGBM_3                    4.7200                 5.5703
#
#               N:GEXP::ATXN2L:11273:  N:GEXP::ZNF396:252884:  \
# LGGGBM
# TCGA-02-0001                 5.1913                  2.9851
# TCGA-02-0003                 5.2753                  2.7672
# TCGA-02-0006                 5.3423                  2.3384
# TCGA-02-0007                 5.5733                  3.9018
# TCGA-02-0009                 5.0130                  3.8957
# ...                             ...                     ...
# TCGA-TQ-A7RS                 5.3960                  3.6285
# TCGA-TQ-A7RU                 5.4928                  3.4970
# TCGA-TQ-A7RV                 5.4264                  3.5015
# TCGA-TQ-A7RW                 5.2656                  3.6693
# TCGA-VW-A7QS                 6.2665                  2.8892
#
#               N:GEXP::BDH2:56898:  N:GEXP::DAG1:1605:  N:GEXP::PCDH12:51294:  \
# LGGGBM
# TCGA-02-0001               5.3609              6.9554                 5.4571
# TCGA-02-0003               4.8107              6.1299                 4.6574
# TCGA-02-0006               5.6326              6.1613                 4.8609
# TCGA-02-0007               5.9383              6.1223                 3.8308
# TCGA-02-0009               5.6487              7.3352                 4.8549
# ...                           ...                 ...                    ...
# TCGA-TQ-A7RS               5.5578              5.7789                 3.4278
# TCGA-TQ-A7RU               4.8238              6.0471                 5.4559
# TCGA-TQ-A7RV               5.8118              5.7703                 4.7208
# TCGA-TQ-A7RW               5.1996              5.1524                 5.0701
# TCGA-VW-A7QS               5.5988              5.6607                 4.7865
#
#               N:GEXP::SLC20A2:6575:  N:GEXP::APAF1:317:  ...  \
# LGGGBM                                                   ...
# TCGA-02-0001                 5.6188              4.1824  ...
# TCGA-02-0003                 5.8621              4.1852  ...
# TCGA-02-0006                 6.8642              4.0793  ...
# TCGA-02-0007                 5.3136              4.6426  ...
# TCGA-02-0009                 7.2952              4.3387  ...
# ...                             ...                 ...  ...
# TCGA-TQ-A7RS                 6.2327              4.0282  ...
# TCGA-TQ-A7RU                 5.9297              4.1216  ...
# TCGA-TQ-A7RV                 6.7460              3.9056  ...
# TCGA-TQ-A7RW                 6.4764              4.5801  ...
# TCGA-VW-A7QS                 5.7654              3.9027  ...
#
#               N:GEXP::XYLB:9942:  N:GEXP::ZNF671:79891:  \
# LGGGBM
# TCGA-02-0001            2.599900                 4.2451
# TCGA-02-0003            2.737700                 5.2227
# TCGA-02-0006            2.950900                 4.5238
# TCGA-02-0007            3.550600                 5.5836
# TCGA-02-0009            1.994500                 5.6635
# ...                          ...                    ...
# TCGA-TQ-A7RS           -0.051951                 4.7065
# TCGA-TQ-A7RU            1.679900                 4.8205
# TCGA-TQ-A7RV            1.783700                 5.3657
# TCGA-TQ-A7RW            2.426600                 4.6815
# TCGA-VW-A7QS            2.123700                 3.9105
#
#               N:GEXP::CCDC69:26112:  N:GEXP::DOK6:220164:  \
# LGGGBM
# TCGA-02-0001                 3.4030               3.36890
# TCGA-02-0003                 3.2129               5.01260
# TCGA-02-0006                 3.8493               1.46680
# TCGA-02-0007                 3.6144               4.48250
# TCGA-02-0009                 3.2583               0.55557
# ...                             ...                   ...
# TCGA-TQ-A7RS                 1.8750               5.31000
# TCGA-TQ-A7RU                 2.0656               5.80860
# TCGA-TQ-A7RV                 3.0031               5.32760
# TCGA-TQ-A7RW                 2.9257               3.32940
# TCGA-VW-A7QS                 2.0025               4.89790
#
#               N:GEXP::PAPOLG:64895:  N:GEXP::KIAA1522:57648:  \
# LGGGBM
# TCGA-02-0001                 3.5242                   4.1537
# TCGA-02-0003                 4.4893                   3.3730
# TCGA-02-0006                 4.8871                   3.8262
# TCGA-02-0007                 3.6058                   5.5075
# TCGA-02-0009                 4.3018                   4.2936
# ...                             ...                      ...
# TCGA-TQ-A7RS                 3.7990                   2.2815
# TCGA-TQ-A7RU                 4.4020                   1.8017
# TCGA-TQ-A7RV                 3.7624                   2.5913
# TCGA-TQ-A7RW                 4.8483                   1.1432
# TCGA-VW-A7QS                 3.7892                   1.2892
#
#               N:GEXP::TM2D1:83941:  N:GEXP::CNNM3:26505:  \
# LGGGBM
# TCGA-02-0001                5.1163                4.0088
# TCGA-02-0003                5.5160                3.8941
# TCGA-02-0006                5.3228                3.9925
# TCGA-02-0007                6.0400                4.2996
# TCGA-02-0009                4.5694                5.3132
# ...                            ...                   ...
# TCGA-TQ-A7RS                3.5931                5.3521
# TCGA-TQ-A7RU                3.4829                5.3518
# TCGA-TQ-A7RV                4.3681                4.6931
# TCGA-TQ-A7RW                4.2509                4.7901
# TCGA-VW-A7QS                3.6194                4.0424
#
#               N:GEXP::DNAJC14:85406:  N:GEXP::ARHGEF10L:55160:
# LGGGBM
# TCGA-02-0001                  4.6568                    6.1494
# TCGA-02-0003                  4.2819                    5.5656
# TCGA-02-0006                  4.4570                    5.6592
# TCGA-02-0007                  4.4147                    6.4061
# TCGA-02-0009                  4.7562                    6.7315
# ...                              ...                       ...
# TCGA-TQ-A7RS                  4.6142                    6.3016
# TCGA-TQ-A7RU                  4.7457                    6.1232
# TCGA-TQ-A7RV                  4.5416                    7.5308
# TCGA-TQ-A7RW                  4.6921                    7.1775
# TCGA-VW-A7QS                  4.8109                    5.9382
#
# [782 rows x 12340 columns]

# %% [markdown]
# #### No LGGGBM intersection section

# %%
sorted(glob.glob('GEXP/*.tsv'))
# Out:
# ['GEXP/ACC_GEXP.tsv',
#  'GEXP/BLCA_GEXP.tsv',
#  'GEXP/BRCA_GEXP.tsv',
#  'GEXP/CESC_GEXP.tsv',
#  'GEXP/COADREAD_GEXP.tsv',
#  'GEXP/ESCC_GEXP.tsv',
#  'GEXP/GEA_GEXP.tsv',
#  'GEXP/HNSC_GEXP.tsv',
#  'GEXP/KIRCKICH_GEXP.tsv',
#  'GEXP/KIRP_GEXP.tsv',
#  'GEXP/LGGGBM_GEXP.tsv',
#  'GEXP/LIHCCHOL_GEXP.tsv',
#  'GEXP/LUAD_GEXP.tsv',
#  'GEXP/LUSC_GEXP.tsv',
#  'GEXP/MESO_GEXP.tsv',
#  'GEXP/OV_GEXP.tsv',
#  'GEXP/PAAD_GEXP.tsv',
#  'GEXP/PCPG_GEXP.tsv',
#  'GEXP/PRAD_GEXP.tsv',
#  'GEXP/SARC_GEXP.tsv',
#  'GEXP/SKCM_GEXP.tsv',
#  'GEXP/TGCT_GEXP.tsv',
#  'GEXP/THCA_GEXP.tsv',
#  'GEXP/THYM_GEXP.tsv',
#  'GEXP/UCEC_GEXP.tsv',
#  'GEXP/UVM_GEXP.tsv']

# %%
no_LGGGBM = ['GEXP/ACC_GEXP.tsv',
 'GEXP/BLCA_GEXP.tsv',
 'GEXP/BRCA_GEXP.tsv',
 'GEXP/CESC_GEXP.tsv',
 'GEXP/COADREAD_GEXP.tsv',
 'GEXP/ESCC_GEXP.tsv',
 'GEXP/GEA_GEXP.tsv',
 'GEXP/HNSC_GEXP.tsv',
 'GEXP/KIRCKICH_GEXP.tsv',
 'GEXP/KIRP_GEXP.tsv',
 # 'GEXP/LGGGBM_GEXP.tsv',
 'GEXP/LIHCCHOL_GEXP.tsv',
 'GEXP/LUAD_GEXP.tsv',
 'GEXP/LUSC_GEXP.tsv',
 'GEXP/MESO_GEXP.tsv',
 'GEXP/OV_GEXP.tsv',
 'GEXP/PAAD_GEXP.tsv',
 'GEXP/PCPG_GEXP.tsv',
 'GEXP/PRAD_GEXP.tsv',
 'GEXP/SARC_GEXP.tsv',
 'GEXP/SKCM_GEXP.tsv',
 'GEXP/TGCT_GEXP.tsv',
 'GEXP/THCA_GEXP.tsv',
 'GEXP/THYM_GEXP.tsv',
 'GEXP/UCEC_GEXP.tsv',
 'GEXP/UVM_GEXP.tsv']

# %%
no_LG_lol_inline = [] # No LGGGBM
for gexp_path in no_LGGGBM:
    print(gexp_path)
    gexp_file = pd.read_csv(gexp_path, sep = '\t', index_col = 0)
    no_LG_lol_inline.append(gexp_file.columns[1:])
intrsct = set.intersection(*map(set,no_LG_lol_inline))
# Out:
# GEXP/ACC_GEXP.tsv
# GEXP/BLCA_GEXP.tsv
# GEXP/BRCA_GEXP.tsv
# GEXP/CESC_GEXP.tsv
# GEXP/COADREAD_GEXP.tsv
# GEXP/ESCC_GEXP.tsv
# GEXP/GEA_GEXP.tsv
# GEXP/HNSC_GEXP.tsv
# GEXP/KIRCKICH_GEXP.tsv
# GEXP/KIRP_GEXP.tsv
# GEXP/LIHCCHOL_GEXP.tsv
# GEXP/LUAD_GEXP.tsv
# GEXP/LUSC_GEXP.tsv
# GEXP/MESO_GEXP.tsv
# GEXP/OV_GEXP.tsv
# GEXP/PAAD_GEXP.tsv
# GEXP/PCPG_GEXP.tsv
# GEXP/PRAD_GEXP.tsv
# GEXP/SARC_GEXP.tsv
# GEXP/SKCM_GEXP.tsv
# GEXP/TGCT_GEXP.tsv
# GEXP/THCA_GEXP.tsv
# GEXP/THYM_GEXP.tsv
# GEXP/UCEC_GEXP.tsv
# GEXP/UVM_GEXP.tsv

# %%
len(intrsct)
# Out:
# 17176

# %%
ntrsct_list = list(intrsct)
lbld_ntrsct_list = ['Labels'] + ntrsct_list

# %%
# Write no LGGGBM across-TCGA intersection files
for gexp_path in no_LGGGBM:
    print(gexp_path)
    gexp_file = pd.read_csv(gexp_path, sep = '\t', index_col = 0)
    intrsct_gexp_file = gexp_file.loc[:, lbld_ntrsct_list]
    intrsct_gexp_file.to_csv('GEXP_intersection_no_LGGGBM/' +
                gexp_file.index.name + '_GEXP_intrsct_no_LGGGBM.tsv', sep = '\t')    
    # break
# Out:
# GEXP/ACC_GEXP.tsv
# GEXP/BLCA_GEXP.tsv
# GEXP/BRCA_GEXP.tsv
# GEXP/CESC_GEXP.tsv
# GEXP/COADREAD_GEXP.tsv
# GEXP/ESCC_GEXP.tsv
# GEXP/GEA_GEXP.tsv
# GEXP/HNSC_GEXP.tsv
# GEXP/KIRCKICH_GEXP.tsv
# GEXP/KIRP_GEXP.tsv
# GEXP/LIHCCHOL_GEXP.tsv
# GEXP/LUAD_GEXP.tsv
# GEXP/LUSC_GEXP.tsv
# GEXP/MESO_GEXP.tsv
# GEXP/OV_GEXP.tsv
# GEXP/PAAD_GEXP.tsv
# GEXP/PCPG_GEXP.tsv
# GEXP/PRAD_GEXP.tsv
# GEXP/SARC_GEXP.tsv
# GEXP/SKCM_GEXP.tsv
# GEXP/TGCT_GEXP.tsv
# GEXP/THCA_GEXP.tsv
# GEXP/THYM_GEXP.tsv
# GEXP/UCEC_GEXP.tsv
# GEXP/UVM_GEXP.tsv

# %%
# End no_LGGGBM intersection file write; three of five dirs done

# %% [markdown]
# #### Within MAD set one - with LGGGBM

# %%
# Populate within dir, direct from GEXP because intersection is not relevant
    # Scientific question - is it worth it to drop LGGGBM in terms getting quality embeddings?
# from a_ series in the g_devel dir

# %%
# Write within-MAD files from the GEXP file set
k = 5000
for gexp_path in sorted(glob.glob('GEXP/*.tsv')):

    print(gexp_path)
    gexp_file = pd.read_csv(gexp_path, sep = '\t', index_col = 0)
    c = gexp_file.index.name
    # features = gexp_file.iloc[:, 1:].mad().sort_values(ascending=False)[:5000].index
    # features = gexp_file.iloc[:, 1:].(gexp_file - gexp_file.mean()).abs().mean().sort_values(ascending=False)[:5000].index
    features = (gexp_file.iloc[:, 1:] - gexp_file.iloc[:, 1:].mean()).abs().mean().sort_values(ascending=False)[:k].index
    gexp_file_nk = gexp_file.loc[:, features]
    max_col_vals = gexp_file_nk.max()
    X_train = (gexp_file_nk / max_col_vals) # Normalization by column
    # break    
    
    X_labeled = pd.concat( [pd.DataFrame(gexp_file.Labels), X_train] ,
                     axis = 1)
    X_labeled.index.name = c
    
    X_labeled.to_csv('GEXP_MAD_5k_within/'+c+'_within_'+str(k)+'k.tsv',
                   sep = '\t')
    break
# intrsct = set.intersection(*map(set,lol_inline))
# Out:
# GEXP/ACC_GEXP.tsv

# %%
check_file = pd.read_csv('GEXP_MAD_5k_within/'+c+'_within_'+str(k)+'k.tsv',
                         sep = '\t',
                         index_col = 0)

# %%
check_file # Looks normalized, procedd to writing two across file sets
# Out:
#              Labels  N:GEXP::IGF2:3481:  N:GEXP::DLK1:8788:  \
# ACC
# TCGA-OR-A5J1  ACC_2            0.179084            0.010742
# TCGA-OR-A5J2  ACC_2            0.179990            0.287300
# TCGA-OR-A5J3  ACC_3            0.021586            0.431374
# TCGA-OR-A5J5  ACC_3            0.107586            0.364419
# TCGA-OR-A5J6  ACC_1            0.472886            0.132366
# ...             ...                 ...                 ...
# TCGA-OU-A5PI  ACC_3            0.005338            0.008791
# TCGA-PA-A5YG  ACC_1            0.037978            0.019161
# TCGA-PK-A5H9  ACC_1            0.346736            0.073886
# TCGA-PK-A5HA  ACC_1            0.177497            0.000300
# TCGA-PK-A5HB  ACC_2            0.088697            0.003648
#
#               N:GEXP::CYP17A1:1586:  N:GEXP::APOE:348:  N:GEXP::STAR:6770:  \
# ACC
# TCGA-OR-A5J1               0.021923           0.038378            0.110853
# TCGA-OR-A5J2               0.005302           0.009819            0.030127
# TCGA-OR-A5J3               0.372870           0.031040            0.257731
# TCGA-OR-A5J5               0.288308           0.009218            0.213982
# TCGA-OR-A5J6               0.647770           0.252118            0.569321
# ...                             ...                ...                 ...
# TCGA-OU-A5PI               0.092080           0.012522            0.147812
# TCGA-PA-A5YG               0.000937           0.005917            0.137388
# TCGA-PK-A5H9               0.150393           0.139675            0.169064
# TCGA-PK-A5HA               0.000614           0.008947            0.148900
# TCGA-PK-A5HB               0.324789           0.002129            0.199853
#
#               N:GEXP::CYP11B1:1584:  N:GEXP::GAPDH:2597:  \
# ACC
# TCGA-OR-A5J1               0.006375             0.163189
# TCGA-OR-A5J2               0.000036             0.126989
# TCGA-OR-A5J3               0.064836             0.762671
# TCGA-OR-A5J5               0.002201             0.359412
# TCGA-OR-A5J6               0.414665             0.128481
# ...                             ...                  ...
# TCGA-OU-A5PI               0.000194             0.251259
# TCGA-PA-A5YG               0.035584             0.278676
# TCGA-PK-A5H9               0.155130             0.054403
# TCGA-PK-A5HA               0.008981             0.197718
# TCGA-PK-A5HB               0.039437             0.120800
#
#               N:GEXP::CYP21A2:1589:  N:GEXP::SPARC:6678:  ...  \
# ACC                                                       ...
# TCGA-OR-A5J1               0.683056             0.112090  ...
# TCGA-OR-A5J2               0.169569             0.205230  ...
# TCGA-OR-A5J3               0.113664             0.122580  ...
# TCGA-OR-A5J5               0.214880             0.113344  ...
# TCGA-OR-A5J6               0.497277             0.106461  ...
# ...                             ...                  ...  ...
# TCGA-OU-A5PI               0.123380             0.171407  ...
# TCGA-PA-A5YG               0.016930             0.075882  ...
# TCGA-PK-A5H9               0.001877             0.084531  ...
# TCGA-PK-A5HA               0.002743             0.080234  ...
# TCGA-PK-A5HB               0.098339             0.432895  ...
#
#               N:GEXP::GIYD2:79008:  N:GEXP::PTEN:5728:  N:GEXP::RAI1:10743:  \
# ACC
# TCGA-OR-A5J1              0.553085            0.324945             0.287928
# TCGA-OR-A5J2              0.138774            1.000000             0.676662
# TCGA-OR-A5J3              0.297219            0.400649             0.393882
# TCGA-OR-A5J5              0.493671            0.717314             0.263969
# TCGA-OR-A5J6              0.235103            0.307611             0.068490
# ...                            ...                 ...                  ...
# TCGA-OU-A5PI              0.391721            0.714170             0.022050
# TCGA-PA-A5YG              0.273267            0.427528             0.215724
# TCGA-PK-A5H9              0.209672            0.457281             0.148100
# TCGA-PK-A5HA              0.682951            0.523177             0.215279
# TCGA-PK-A5HB              0.279984            0.485445             0.230998
#
#               N:GEXP::UBN1:29855:  N:GEXP::C11orf48:79081:  \
# ACC
# TCGA-OR-A5J1             0.246264                 0.505010
# TCGA-OR-A5J2             0.631863                 0.079529
# TCGA-OR-A5J3             0.354852                 0.087657
# TCGA-OR-A5J5             0.351571                 0.175560
# TCGA-OR-A5J6             0.248789                 0.212524
# ...                           ...                      ...
# TCGA-OU-A5PI             0.568111                 0.063677
# TCGA-PA-A5YG             0.556177                 0.102211
# TCGA-PK-A5H9             0.473769                 0.100391
# TCGA-PK-A5HA             0.414230                 0.109746
# TCGA-PK-A5HB             0.477339                 0.099486
#
#               N:GEXP::UFD1L:7353:  N:GEXP::PLEKHM2:23207:  \
# ACC
# TCGA-OR-A5J1             0.435099                0.346972
# TCGA-OR-A5J2             0.222529                0.609245
# TCGA-OR-A5J3             0.514997                0.283717
# TCGA-OR-A5J5             0.561697                0.353537
# TCGA-OR-A5J6             0.288953                0.351005
# ...                           ...                     ...
# TCGA-OU-A5PI             0.461275                0.241950
# TCGA-PA-A5YG             0.305127                0.416120
# TCGA-PK-A5H9             0.256306                0.411907
# TCGA-PK-A5HA             0.266176                0.381927
# TCGA-PK-A5HB             0.566233                0.561698
#
#               N:GEXP::ATAD3A:55210:  N:GEXP::PLK2:10769:  N:GEXP::TIAL1:7073:
# ACC
# TCGA-OR-A5J1               0.321314             0.170577             0.398191
# TCGA-OR-A5J2               0.095816             0.166556             0.784324
# TCGA-OR-A5J3               0.262076             0.462200             0.283512
# TCGA-OR-A5J5               0.168052             0.133176             0.484654
# TCGA-OR-A5J6               0.375485             0.066781             0.283900
# ...                             ...                  ...                  ...
# TCGA-OU-A5PI               0.131434             0.159023             0.530964
# TCGA-PA-A5YG               0.212865             0.112184             0.250428
# TCGA-PK-A5H9               0.167434             0.095949             0.379815
# TCGA-PK-A5HA               0.154359             0.142507             0.562747
# TCGA-PK-A5HB               0.630464             0.232481             0.512684
#
# [76 rows x 5001 columns]

# %% [markdown]
# #### devel inspect

# %%
ls
# Out:
# ACC_archive/                  dim10/
# GEXP/                         dim100_run0/
# GEXP_MAD_5k_across/           figure_five/
# GEXP_MAD_5k_across_no_LGGGBM/ latent feature inspect/
# GEXP_MAD_5k_within/           latent_feature_objects/
# GEXP_intersection/            learning_curves/
# GEXP_intersection_no_LGGGBM/  loss_plots/
# PDF_out/                      ops_notes.txt
# box_and_whiskers.ipynb        shuffle/
# decoded/                      standard_deviation_plots/

# %%
(gexp_file.iloc[:, 1:] - gexp_file.iloc[:, 1:].mean()).abs().mean().sort_values(ascending=False)[:5000]
# Out:
# N:GEXP::IGF2:3481:        267024.447448
# N:GEXP::DLK1:8788:        200257.033546
# N:GEXP::CYP17A1:1586:     127764.471200
# N:GEXP::APOE:348:          64460.573639
# N:GEXP::STAR:6770:         61143.067230
#                               ...
# N:GEXP::UFD1L:7353:          367.569668
# N:GEXP::PLEKHM2:23207:       367.527299
# N:GEXP::ATAD3A:55210:        367.311468
# N:GEXP::PLK2:10769:          367.285935
# N:GEXP::TIAL1:7073:          367.259643
# Length: 5000, dtype: float64

# %% [markdown]
# #### Within MAD set two - without LGGGBM

# %%
# Omitting, not biologically or matheimatically sensible

# Also not sensible to include the within taken on intersection with or without LGGGBM

# %% [markdown]
# #### Across MAD set one - with LGGGBM

# %%
# from: a_GEXP_5k_col_norm.ipynb in g_devel
# will need to stack here
# and read from the intersection file set
    # read also from this intersection set for the non-LGGGBM set

# %%
k = 5000
for ntrsct_pth in sorted(glob.glob('GEXP_intersection/*.tsv')):
    print(ntrsct_pth)
    file = pd.read_csv(ntrsct_pth, sep = '\t', index_col = 0)
    c = file.index.name
    features = (file.iloc[:, 1:] - file.iloc[:, 1:].mean()).abs().mean().sort_values(ascending=False)[:k].index
    file_nk = file.loc[:, features]
    max_col_vals = file_nk.max()
    X_train = (file_nk / max_col_vals) # Normalization by column
    
    X_labeled = pd.concat( [pd.DataFrame(file.Labels), X_train] ,
                     axis = 1)
    X_labeled.index.name = c
    
    X_labeled.to_csv('GEXP_MAD_5k_across/'+c+'_across_'+str(k)+'k.tsv',
                   sep = '\t')
    # break
# Out:
# GEXP_intersection/ACC_GEXP_intrsct.tsv
# GEXP_intersection/BLCA_GEXP_intrsct.tsv
# GEXP_intersection/BRCA_GEXP_intrsct.tsv
# GEXP_intersection/CESC_GEXP_intrsct.tsv
# GEXP_intersection/COADREAD_GEXP_intrsct.tsv
# GEXP_intersection/ESCC_GEXP_intrsct.tsv
# GEXP_intersection/GEA_GEXP_intrsct.tsv
# GEXP_intersection/HNSC_GEXP_intrsct.tsv
# GEXP_intersection/KIRCKICH_GEXP_intrsct.tsv
# GEXP_intersection/KIRP_GEXP_intrsct.tsv
# GEXP_intersection/LGGGBM_GEXP_intrsct.tsv
# GEXP_intersection/LIHCCHOL_GEXP_intrsct.tsv
# GEXP_intersection/LUAD_GEXP_intrsct.tsv
# GEXP_intersection/LUSC_GEXP_intrsct.tsv
# GEXP_intersection/MESO_GEXP_intrsct.tsv
# GEXP_intersection/OV_GEXP_intrsct.tsv
# GEXP_intersection/PAAD_GEXP_intrsct.tsv
# GEXP_intersection/PCPG_GEXP_intrsct.tsv
# GEXP_intersection/PRAD_GEXP_intrsct.tsv
# GEXP_intersection/SARC_GEXP_intrsct.tsv
# GEXP_intersection/SKCM_GEXP_intrsct.tsv
# GEXP_intersection/TGCT_GEXP_intrsct.tsv
# GEXP_intersection/THCA_GEXP_intrsct.tsv
# GEXP_intersection/THYM_GEXP_intrsct.tsv
# GEXP_intersection/UCEC_GEXP_intrsct.tsv
# GEXP_intersection/UVM_GEXP_intrsct.tsv

# %%
len(file.columns)
# Out:
# 12340

# %%
check_file = pd.read_csv('GEXP_MAD_5k_across/'+c+'_across_'+str(k)+'k.tsv',
                         sep = '\t',
                         index_col = 0)

# %%
check_file

# %% [markdown]
# #### Across MAD set two - without LGGGBM

# %%
k = 5000
for ntrsct_pth in sorted(glob.glob('GEXP_intersection_no_LGGGBM/*.tsv')):
    print(ntrsct_pth)
    file = pd.read_csv(ntrsct_pth, sep = '\t', index_col = 0)
    c = file.index.name
    features = (file.iloc[:, 1:] - file.iloc[:, 1:].mean()).abs().mean().sort_values(ascending=False)[:k].index
    file_nk = file.loc[:, features]
    max_col_vals = file_nk.max()
    X_train = (file_nk / max_col_vals) # Normalization by column
    
    X_labeled = pd.concat( [pd.DataFrame(file.Labels), X_train] ,
                     axis = 1)
    X_labeled.index.name = c
    
    X_labeled.to_csv('GEXP_MAD_5k_across_no_LGGGBM/'+c+'_across_no_LGGGBM_'+str(k)+'k.tsv',
                   sep = '\t')
    # break
# Out:
# GEXP_intersection_no_LGGGBM/ACC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/BLCA_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/BRCA_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/CESC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/COADREAD_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/ESCC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/GEA_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/HNSC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/KIRCKICH_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/KIRP_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/LIHCCHOL_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/LUAD_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/LUSC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/MESO_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/OV_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/PAAD_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/PCPG_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/PRAD_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/SARC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/SKCM_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/TGCT_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/THCA_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/THYM_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/UCEC_GEXP_intrsct_no_LGGGBM.tsv
# GEXP_intersection_no_LGGGBM/UVM_GEXP_intrsct_no_LGGGBM.tsv

# %%
len(file.columns)
# Out:
# 17177

# %%
check_file = pd.read_csv('GEXP_MAD_5k_across_no_LGGGBM/'+c+'_across_no_LGGGBM_'+str(k)+'k.tsv',
                         sep = '\t',
                         index_col = 0)

# %%
check_file

# %% [markdown]
# ### Encoding verification plot, need to automatically inset loss plots

# %% [markdown]
# #### Input F1 setup

# %%
# Start with writing two loss plots - working out of box_whisk repo
    # Want to run a F1 RF input to quality of embedding plot
# Working on ACC, Run the 'within' file first - i_o/GEXP_MAD_5k_within
# Then two across files - i_o/GEXP_MAD_5k_across

# %%
file_paths = sorted(
    glob.glob(
        'i_o/GEXP_MAD_5k_within/*.tsv'))

# %%
file_paths
# Out:
# ['i_o/GEXP_MAD_5k_within/ACC_within_5000k.tsv']

# %%
file = pd.read_csv(
    file_paths[0], sep = '\t', index_col = 0)

# %%
file_paths[0]
# Out:
# 'i_o/GEXP_MAD_5k_within/ACC_within_5000k.tsv'

# %%
file
# Out:
#              Labels  N:GEXP::IGF2:3481:  N:GEXP::DLK1:8788:  \
# ACC
# TCGA-OR-A5J1  ACC_2            0.179084            0.010742
# TCGA-OR-A5J2  ACC_2            0.179990            0.287300
# TCGA-OR-A5J3  ACC_3            0.021586            0.431374
# TCGA-OR-A5J5  ACC_3            0.107586            0.364419
# TCGA-OR-A5J6  ACC_1            0.472886            0.132366
# ...             ...                 ...                 ...
# TCGA-OU-A5PI  ACC_3            0.005338            0.008791
# TCGA-PA-A5YG  ACC_1            0.037978            0.019161
# TCGA-PK-A5H9  ACC_1            0.346736            0.073886
# TCGA-PK-A5HA  ACC_1            0.177497            0.000300
# TCGA-PK-A5HB  ACC_2            0.088697            0.003648
#
#               N:GEXP::CYP17A1:1586:  N:GEXP::APOE:348:  N:GEXP::STAR:6770:  \
# ACC
# TCGA-OR-A5J1               0.021923           0.038378            0.110853
# TCGA-OR-A5J2               0.005302           0.009819            0.030127
# TCGA-OR-A5J3               0.372870           0.031040            0.257731
# TCGA-OR-A5J5               0.288308           0.009218            0.213982
# TCGA-OR-A5J6               0.647770           0.252118            0.569321
# ...                             ...                ...                 ...
# TCGA-OU-A5PI               0.092080           0.012522            0.147812
# TCGA-PA-A5YG               0.000937           0.005917            0.137388
# TCGA-PK-A5H9               0.150393           0.139675            0.169064
# TCGA-PK-A5HA               0.000614           0.008947            0.148900
# TCGA-PK-A5HB               0.324789           0.002129            0.199853
#
#               N:GEXP::CYP11B1:1584:  N:GEXP::GAPDH:2597:  \
# ACC
# TCGA-OR-A5J1               0.006375             0.163189
# TCGA-OR-A5J2               0.000036             0.126989
# TCGA-OR-A5J3               0.064836             0.762671
# TCGA-OR-A5J5               0.002201             0.359412
# TCGA-OR-A5J6               0.414665             0.128481
# ...                             ...                  ...
# TCGA-OU-A5PI               0.000194             0.251259
# TCGA-PA-A5YG               0.035584             0.278676
# TCGA-PK-A5H9               0.155130             0.054403
# TCGA-PK-A5HA               0.008981             0.197718
# TCGA-PK-A5HB               0.039437             0.120800
#
#               N:GEXP::CYP21A2:1589:  N:GEXP::SPARC:6678:  ...  \
# ACC                                                       ...
# TCGA-OR-A5J1               0.683056             0.112090  ...
# TCGA-OR-A5J2               0.169569             0.205230  ...
# TCGA-OR-A5J3               0.113664             0.122580  ...
# TCGA-OR-A5J5               0.214880             0.113344  ...
# TCGA-OR-A5J6               0.497277             0.106461  ...
# ...                             ...                  ...  ...
# TCGA-OU-A5PI               0.123380             0.171407  ...
# TCGA-PA-A5YG               0.016930             0.075882  ...
# TCGA-PK-A5H9               0.001877             0.084531  ...
# TCGA-PK-A5HA               0.002743             0.080234  ...
# TCGA-PK-A5HB               0.098339             0.432895  ...
#
#               N:GEXP::GIYD2:79008:  N:GEXP::PTEN:5728:  N:GEXP::RAI1:10743:  \
# ACC
# TCGA-OR-A5J1              0.553085            0.324945             0.287928
# TCGA-OR-A5J2              0.138774            1.000000             0.676662
# TCGA-OR-A5J3              0.297219            0.400649             0.393882
# TCGA-OR-A5J5              0.493671            0.717314             0.263969
# TCGA-OR-A5J6              0.235103            0.307611             0.068490
# ...                            ...                 ...                  ...
# TCGA-OU-A5PI              0.391721            0.714170             0.022050
# TCGA-PA-A5YG              0.273267            0.427528             0.215724
# TCGA-PK-A5H9              0.209672            0.457281             0.148100
# TCGA-PK-A5HA              0.682951            0.523177             0.215279
# TCGA-PK-A5HB              0.279984            0.485445             0.230998
#
#               N:GEXP::UBN1:29855:  N:GEXP::C11orf48:79081:  \
# ACC
# TCGA-OR-A5J1             0.246264                 0.505010
# TCGA-OR-A5J2             0.631863                 0.079529
# TCGA-OR-A5J3             0.354852                 0.087657
# TCGA-OR-A5J5             0.351571                 0.175560
# TCGA-OR-A5J6             0.248789                 0.212524
# ...                           ...                      ...
# TCGA-OU-A5PI             0.568111                 0.063677
# TCGA-PA-A5YG             0.556177                 0.102211
# TCGA-PK-A5H9             0.473769                 0.100391
# TCGA-PK-A5HA             0.414230                 0.109746
# TCGA-PK-A5HB             0.477339                 0.099486
#
#               N:GEXP::UFD1L:7353:  N:GEXP::PLEKHM2:23207:  \
# ACC
# TCGA-OR-A5J1             0.435099                0.346972
# TCGA-OR-A5J2             0.222529                0.609245
# TCGA-OR-A5J3             0.514997                0.283717
# TCGA-OR-A5J5             0.561697                0.353537
# TCGA-OR-A5J6             0.288953                0.351005
# ...                           ...                     ...
# TCGA-OU-A5PI             0.461275                0.241950
# TCGA-PA-A5YG             0.305127                0.416120
# TCGA-PK-A5H9             0.256306                0.411907
# TCGA-PK-A5HA             0.266176                0.381927
# TCGA-PK-A5HB             0.566233                0.561698
#
#               N:GEXP::ATAD3A:55210:  N:GEXP::PLK2:10769:  N:GEXP::TIAL1:7073:
# ACC
# TCGA-OR-A5J1               0.321314             0.170577             0.398191
# TCGA-OR-A5J2               0.095816             0.166556             0.784324
# TCGA-OR-A5J3               0.262076             0.462200             0.283512
# TCGA-OR-A5J5               0.168052             0.133176             0.484654
# TCGA-OR-A5J6               0.375485             0.066781             0.283900
# ...                             ...                  ...                  ...
# TCGA-OU-A5PI               0.131434             0.159023             0.530964
# TCGA-PA-A5YG               0.212865             0.112184             0.250428
# TCGA-PK-A5H9               0.167434             0.095949             0.379815
# TCGA-PK-A5HA               0.154359             0.142507             0.562747
# TCGA-PK-A5HB               0.630464             0.232481             0.512684
#
# [76 rows x 5001 columns]

# %%
pwd
# Out:
# '/Users/karlberb/Documents/work/sample_count/synthetic_TCGA_data_gen/g_learning_curves/i_o'

# %%
ls i_o/
# Out:
# ACC_archive/                  dim10/
# GEXP/                         dim100_run0/
# GEXP_MAD_5k_across/           figure_five/
# GEXP_MAD_5k_across_no_LGGGBM/ latent feature inspect/
# GEXP_MAD_5k_within/           latent_feature_objects/
# GEXP_intersection/            learning_curves/
# GEXP_intersection_no_LGGGBM/  loss_plots/
# PDF_out/                      ops_notes.txt
# box_whisk/                    shuffle/
# decoded/                      standard_deviation_plots/

# %%
# going to free-write then manully clean up the i_o post-hoc
    # file write paths will be untracable, don't care, fix in box_whisk_v2

# %%
df_to_rf = brca_5k_across # <---
feature_selection_method = 'across_cohort'

# %% [markdown]
# #### Input F1 Main

# %%
# Write a F1 input object to box_whisk i_o dir
inpt_frame = pd.DataFrame()
print('Starting a quality of embedding F1 object generation run')
# Need to track the loss plots off the back-end

# inpt_emb_qual_F1_means = {}

F1_output = []
trn_tst_splts = 50
for r in list(range(0, trn_tst_splts)):
        
    X = file.iloc[:, 1:]
    y = file.iloc[:, 0]
    X_train, X_test, y_train, y_test = train_test_split(
                X, y,
                    test_size=0.33,
                        )
    clf = RandomForestClassifier()
    clf.fit(X_train, y_train)

    F1_scr = f1_score(y_test, clf.predict(X_test), average='weighted')
    F1_output.append(F1_scr)

    # inpt_emb_qual_F1_means[r] = round(F1_output, 3)
# inpt_frame = pd.DataFrame(F1_output)
# F1_output
print('Learning curve object generated, send to plot function')
# Out:
# Starting a quality of embedding F1 object generation run
# Learning curve object generated, send to plot function

# %%
inpt_frame = pd.DataFrame(F1_output, columns = ['F1s'])

# %%
config = 'MAD_5k_within'

# %%
inpt_frame.insert(0, 'train_config', config)

# %%
inpt_frame.head(1)
# Out:
#     train_config       F1s
# 0  MAD_5k_within  0.829767

# %%
inpt_frame.shape
# Out:
# (50, 2)

# %%
sns.boxplot(F1_output, color = sns.color_palette("hls", 7)[4])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### VAE

# %% [markdown]
# #### VAE Setup

# %%
# Function set for leave one out loop
def compute_latent(x): # x:
    mu, sigma = x
    batch = K.shape(mu)[0]
    dim = K.shape(mu)[1]
    eps = K.random_normal(shape=(batch,dim), mean=0., stddev=1.0 )
    return mu + K.exp(sigma/2)*eps

# Set custom layer , will need all this at start of shell script
class CustomVariationalLayer(Layer):
    """
    Define a custom layer
    """
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomVariationalLayer, self).__init__(**kwargs)

    def vae_loss(self, x_input, x_decoded):
        reconstruction_loss = original_dim * metrics.binary_crossentropy(x_input, x_decoded)
        kl_loss = - 0.5 * K.sum(1 + z_log_var_encoded - K.square(z_mean_encoded) - 
                                K.exp(z_log_var_encoded), axis=-1)
        return K.mean(reconstruction_loss + (K.get_value(beta) * kl_loss))

    def call(self, inputs):
        x = inputs[0]
        x_decoded = inputs[1]
        loss = self.vae_loss(x, x_decoded)
        self.add_loss(loss, inputs=inputs)
        return x
    
class WarmUpCallback(Callback):
    def __init__(self, beta, kappa):
        self.beta = beta
        self.kappa = kappa

    def on_epoch_end(self, epoch, logs={}):
        if K.get_value(self.beta) <= 1:
            K.set_value(self.beta, K.get_value(self.beta) + self.kappa)

# %% [markdown]
# #### VAE Main

# %%
feature_set = 'mad_5k_within'
decode_df = file
c = file.index.name
fit_on = c
super_v = '0'

# %%
c
# Out:
# 'ACC'

# %%
fit_on
# Out:
# 'ACC'

# %%
decode_df
# Out:
#              Labels  N:GEXP::IGF2:3481:  N:GEXP::DLK1:8788:  \
# ACC
# TCGA-OR-A5J1  ACC_2            0.179084            0.010742
# TCGA-OR-A5J2  ACC_2            0.179990            0.287300
# TCGA-OR-A5J3  ACC_3            0.021586            0.431374
# TCGA-OR-A5J5  ACC_3            0.107586            0.364419
# TCGA-OR-A5J6  ACC_1            0.472886            0.132366
# ...             ...                 ...                 ...
# TCGA-OU-A5PI  ACC_3            0.005338            0.008791
# TCGA-PA-A5YG  ACC_1            0.037978            0.019161
# TCGA-PK-A5H9  ACC_1            0.346736            0.073886
# TCGA-PK-A5HA  ACC_1            0.177497            0.000300
# TCGA-PK-A5HB  ACC_2            0.088697            0.003648
#
#               N:GEXP::CYP17A1:1586:  N:GEXP::APOE:348:  N:GEXP::STAR:6770:  \
# ACC
# TCGA-OR-A5J1               0.021923           0.038378            0.110853
# TCGA-OR-A5J2               0.005302           0.009819            0.030127
# TCGA-OR-A5J3               0.372870           0.031040            0.257731
# TCGA-OR-A5J5               0.288308           0.009218            0.213982
# TCGA-OR-A5J6               0.647770           0.252118            0.569321
# ...                             ...                ...                 ...
# TCGA-OU-A5PI               0.092080           0.012522            0.147812
# TCGA-PA-A5YG               0.000937           0.005917            0.137388
# TCGA-PK-A5H9               0.150393           0.139675            0.169064
# TCGA-PK-A5HA               0.000614           0.008947            0.148900
# TCGA-PK-A5HB               0.324789           0.002129            0.199853
#
#               N:GEXP::CYP11B1:1584:  N:GEXP::GAPDH:2597:  \
# ACC
# TCGA-OR-A5J1               0.006375             0.163189
# TCGA-OR-A5J2               0.000036             0.126989
# TCGA-OR-A5J3               0.064836             0.762671
# TCGA-OR-A5J5               0.002201             0.359412
# TCGA-OR-A5J6               0.414665             0.128481
# ...                             ...                  ...
# TCGA-OU-A5PI               0.000194             0.251259
# TCGA-PA-A5YG               0.035584             0.278676
# TCGA-PK-A5H9               0.155130             0.054403
# TCGA-PK-A5HA               0.008981             0.197718
# TCGA-PK-A5HB               0.039437             0.120800
#
#               N:GEXP::CYP21A2:1589:  N:GEXP::SPARC:6678:  ...  \
# ACC                                                       ...
# TCGA-OR-A5J1               0.683056             0.112090  ...
# TCGA-OR-A5J2               0.169569             0.205230  ...
# TCGA-OR-A5J3               0.113664             0.122580  ...
# TCGA-OR-A5J5               0.214880             0.113344  ...
# TCGA-OR-A5J6               0.497277             0.106461  ...
# ...                             ...                  ...  ...
# TCGA-OU-A5PI               0.123380             0.171407  ...
# TCGA-PA-A5YG               0.016930             0.075882  ...
# TCGA-PK-A5H9               0.001877             0.084531  ...
# TCGA-PK-A5HA               0.002743             0.080234  ...
# TCGA-PK-A5HB               0.098339             0.432895  ...
#
#               N:GEXP::GIYD2:79008:  N:GEXP::PTEN:5728:  N:GEXP::RAI1:10743:  \
# ACC
# TCGA-OR-A5J1              0.553085            0.324945             0.287928
# TCGA-OR-A5J2              0.138774            1.000000             0.676662
# TCGA-OR-A5J3              0.297219            0.400649             0.393882
# TCGA-OR-A5J5              0.493671            0.717314             0.263969
# TCGA-OR-A5J6              0.235103            0.307611             0.068490
# ...                            ...                 ...                  ...
# TCGA-OU-A5PI              0.391721            0.714170             0.022050
# TCGA-PA-A5YG              0.273267            0.427528             0.215724
# TCGA-PK-A5H9              0.209672            0.457281             0.148100
# TCGA-PK-A5HA              0.682951            0.523177             0.215279
# TCGA-PK-A5HB              0.279984            0.485445             0.230998
#
#               N:GEXP::UBN1:29855:  N:GEXP::C11orf48:79081:  \
# ACC
# TCGA-OR-A5J1             0.246264                 0.505010
# TCGA-OR-A5J2             0.631863                 0.079529
# TCGA-OR-A5J3             0.354852                 0.087657
# TCGA-OR-A5J5             0.351571                 0.175560
# TCGA-OR-A5J6             0.248789                 0.212524
# ...                           ...                      ...
# TCGA-OU-A5PI             0.568111                 0.063677
# TCGA-PA-A5YG             0.556177                 0.102211
# TCGA-PK-A5H9             0.473769                 0.100391
# TCGA-PK-A5HA             0.414230                 0.109746
# TCGA-PK-A5HB             0.477339                 0.099486
#
#               N:GEXP::UFD1L:7353:  N:GEXP::PLEKHM2:23207:  \
# ACC
# TCGA-OR-A5J1             0.435099                0.346972
# TCGA-OR-A5J2             0.222529                0.609245
# TCGA-OR-A5J3             0.514997                0.283717
# TCGA-OR-A5J5             0.561697                0.353537
# TCGA-OR-A5J6             0.288953                0.351005
# ...                           ...                     ...
# TCGA-OU-A5PI             0.461275                0.241950
# TCGA-PA-A5YG             0.305127                0.416120
# TCGA-PK-A5H9             0.256306                0.411907
# TCGA-PK-A5HA             0.266176                0.381927
# TCGA-PK-A5HB             0.566233                0.561698
#
#               N:GEXP::ATAD3A:55210:  N:GEXP::PLK2:10769:  N:GEXP::TIAL1:7073:
# ACC
# TCGA-OR-A5J1               0.321314             0.170577             0.398191
# TCGA-OR-A5J2               0.095816             0.166556             0.784324
# TCGA-OR-A5J3               0.262076             0.462200             0.283512
# TCGA-OR-A5J5               0.168052             0.133176             0.484654
# TCGA-OR-A5J6               0.375485             0.066781             0.283900
# ...                             ...                  ...                  ...
# TCGA-OU-A5PI               0.131434             0.159023             0.530964
# TCGA-PA-A5YG               0.212865             0.112184             0.250428
# TCGA-PK-A5H9               0.167434             0.095949             0.379815
# TCGA-PK-A5HA               0.154359             0.142507             0.562747
# TCGA-PK-A5HB               0.630464             0.232481             0.512684
#
# [76 rows x 5001 columns]

# %%
ls i_o/box_whisk/

# %%
# dir is actually empty

# %%
ls i_o/
# Out:
# ACC_archive/                  dim10/
# GEXP/                         dim100_run0/
# GEXP_MAD_5k_across/           figure_five/
# GEXP_MAD_5k_across_no_LGGGBM/ latent feature inspect/
# GEXP_MAD_5k_within/           latent_feature_objects/
# GEXP_intersection/            learning_curves/
# GEXP_intersection_no_LGGGBM/  loss_plots/
# PDF_out/                      ops_notes.txt
# box_whisk/                    shuffle/
# decoded/                      standard_deviation_plots/

# %%
itr = 'box_whisk'

# %%
# Decode all samples after training on self with MAD 5k taken
  # either within or across cohort
# from shuffle in g_learning_curves

features = decode_df.columns[1:] # direct decode, will need fitting / dedoding frames

original_dim = len(features)
feature_dim = len(features)
latent_dim = 100               # Toggle here, to plot labels!

encoder_inputs = keras.Input(shape=(feature_dim,))
z_mean_dense_linear = layers.Dense(latent_dim, kernel_initializer='glorot_uniform', name="encoder_1")(encoder_inputs)
z_mean_dense_batchnorm = layers.BatchNormalization()(z_mean_dense_linear)
z_mean_encoded = layers.Activation('relu')(z_mean_dense_batchnorm)

z_log_var_dense_linear = layers.Dense(latent_dim, kernel_initializer='glorot_uniform', name="encoder_2")(encoder_inputs)
z_log_var_dense_batchnorm = layers.BatchNormalization()(z_log_var_dense_linear)
z_log_var_encoded = layers.Activation('relu')(z_log_var_dense_batchnorm)

latent_space = layers.Lambda(compute_latent, output_shape=(latent_dim,), name="latent_space")([z_mean_encoded, z_log_var_encoded])

decoder_to_reconstruct = layers.Dense(feature_dim, kernel_initializer='glorot_uniform', activation='sigmoid')
decoder_outputs = decoder_to_reconstruct(latent_space)

learning_rate = 0.0005
kappa = 1

beta = K.variable(0)

adam = optimizers.Adam(learning_rate=learning_rate)
vae_layer = CustomVariationalLayer()([encoder_inputs, decoder_outputs])
vae = Model(encoder_inputs, vae_layer)
vae.compile(optimizer=adam, loss=None, loss_weights=[beta])

epochs=160

fit_start = time.time()
history = vae.fit(decode_df.iloc[:, 1:],  #       <-------- fit the VAE on object toggled here
            epochs=epochs, batch_size=50, shuffle=True,
            callbacks=[WarmUpCallback(beta, kappa)],
                 verbose=0 #  <---------------------- turn this on for production *************
                 )
fit_end = time.time() - fit_start

plt.plot(history.history['loss'],label="loss")

plt.title(
    c+' fit '+
    '\nTybalt VAE\n'
         )
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.annotate('Feature set = '+feature_set+
             '\nLatent dim = '+str(latent_dim)+
             '\nLayer type = dense'+
             '\nNormalization = divide by max(),\n'+
             '                       column-wise,\n'+
             '                       within cohort'+
             '\nFit time = '+str(round(fit_end,2 ))+'s',
            xy=(.4, .8), xycoords='figure fraction',
            horizontalalignment='left', verticalalignment='top',
            )

plt.legend(loc="lower left")
plt.savefig(
    'i_o/'+itr+'/'+c+'_'+
    'fit_on_'+fit_on+'_latent_dim.'+str(latent_dim)+
    # '_pltv-'+str(plt_v)+
    '_epochs.'+str(epochs)+'_'+
    feature_set+super_v+
    '.png', bbox_inches='tight') # version 18, norm within cohort
# plt.close()

encoder = Model(encoder_inputs, z_mean_encoded)
decoder_input = keras.Input(shape=(latent_dim, ))
_x_decoded_mean = decoder_to_reconstruct(decoder_input)
decoder = Model(decoder_input, _x_decoded_mean)

y_df = decode_df.Labels

decoded = pd.DataFrame(decoder.predict(encoder.predict(decode_df.iloc[:, 1:])),
                       index=decode_df.index, columns=decode_df.iloc[:, 1:].columns)

latent_object = pd.DataFrame(encoder.predict(decode_df.iloc[:, 1:]),
             index=decode_df.index,
                # columns=decode_df.iloc[:, 1:].columns # Columns are different because this is latent space
        )
latent_object.index.name = c
latent_object = pd.concat( [pd.DataFrame(y_df), latent_object] , axis =1)
latent_object.to_csv('i_o/'+itr+'/'+c+'_fit_on.'+fit_on+
                     '_latent_object_latent_dim.'+str(latent_dim)+
    '_epochs.'+str(epochs)+'_'+feature_set+super_v+
    '.tsv',
    sep = '\t')
# break
decoded_labeled = pd.concat( [pd.DataFrame(y_df), decoded] , axis =1)
decoded_labeled.to_csv(
    'i_o/'+itr+'/'+c+'_fit_on.'+fit_on+'_decoded_latent_dim.'+
    str(latent_dim)+
    '_epochs.'+str(epochs)+'_'+feature_set+super_v+
    '.tsv',
    sep = '\t')

print('Decode cohort trained on self using '+feature_set+' feature set experiment done')
# Out:
# WARNING:tensorflow:Output {0} missing from loss dictionary. We assume this was done on purpose. The fit and evaluate APIs will not be expecting any data to be passed to custom_variational_layer_7.
# 2022-12-05 15:18:48.726116: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:48.829116: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:48.875696: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:49.096183: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:49.207906: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:49.253119: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:49.861984: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# /Users/karlberb/miniforge3/envs/tf_M1_py3dot9/lib/python3.9/site-packages/keras/engine/training_v1.py:2356: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 2022-12-05 15:18:53.841364: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2022-12-05 15:18:53.995607: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Decode cohort trained on self using mad_5k_within feature set experiment done

# %%
# Observation: Higher dimensionality of latent feature space reduces
    # the number of training epochs needed to flatten the curve

# %% [markdown]
# #### Read dec for F1 scoring

# %%
# nest the files in the box_whisk i_o folder
    # by cohort
    # then by feature selection method

# %%
# try a grey-scale boxplot
    # Or even black and white
    # need auto file read
    # just start with two plots

# %%
# This thing wants to read from a single dataframe

# %%
ls i_o/box_whisk/
# Out:
# ACC_fit_on.ACC_decoded_latent_dim.100_epochs.160_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.100_epochs.320_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.100_epochs.500_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.100_epochs.700_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.10_epochs.160_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.10_epochs.320_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.10_epochs.500_mad_5k_within0.tsv
# ACC_fit_on.ACC_decoded_latent_dim.10_epochs.700_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.100_epochs.160_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.100_epochs.320_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.100_epochs.500_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.100_epochs.700_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.10_epochs.160_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.10_epochs.320_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.10_epochs.500_mad_5k_within0.tsv
# ACC_fit_on.ACC_latent_object_latent_dim.10_epochs.700_mad_5k_within0.tsv
# ACC_fit_on_ACC_latent_dim.100_epochs.160_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.100_epochs.320_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.100_epochs.500_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.100_epochs.700_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.10_epochs.160_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.10_epochs.320_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.10_epochs.500_mad_5k_within0.png
# ACC_fit_on_ACC_latent_dim.10_epochs.700_mad_5k_within0.png

# %%
dec_1 = pd.read_csv(
    'i_o/box_whisk/ACC_fit_on.ACC_decoded_latent_dim.100_epochs.160_mad_5k_within0.tsv',
    sep = '\t', index_col = 0)

# %%
dec_1
# Out:
#              Labels  N:GEXP::IGF2:3481:  N:GEXP::DLK1:8788:  \
# ACC
# TCGA-OR-A5J1  ACC_2            0.190378            0.266809
# TCGA-OR-A5J2  ACC_2            0.072480            0.179206
# TCGA-OR-A5J3  ACC_3            0.084782            0.284027
# TCGA-OR-A5J5  ACC_3            0.152498            0.410618
# TCGA-OR-A5J6  ACC_1            0.152607            0.242628
# ...             ...                 ...                 ...
# TCGA-OU-A5PI  ACC_3            0.045266            0.160574
# TCGA-PA-A5YG  ACC_1            0.109545            0.183137
# TCGA-PK-A5H9  ACC_1            0.122362            0.140913
# TCGA-PK-A5HA  ACC_1            0.144297            0.188234
# TCGA-PK-A5HB  ACC_2            0.043652            0.119741
#
#               N:GEXP::CYP17A1:1586:  N:GEXP::APOE:348:  N:GEXP::STAR:6770:  \
# ACC
# TCGA-OR-A5J1               0.160986           0.113411            0.177116
# TCGA-OR-A5J2               0.052962           0.035665            0.085281
# TCGA-OR-A5J3               0.281622           0.076587            0.224013
# TCGA-OR-A5J5               0.265335           0.121003            0.164042
# TCGA-OR-A5J6               0.345079           0.158151            0.352949
# ...                             ...                ...                 ...
# TCGA-OU-A5PI               0.142132           0.035180            0.141558
# TCGA-PA-A5YG               0.048496           0.044800            0.273652
# TCGA-PK-A5H9               0.140612           0.097080            0.228469
# TCGA-PK-A5HA               0.045936           0.055555            0.202613
# TCGA-PK-A5HB               0.190163           0.012989            0.077864
#
#               N:GEXP::CYP11B1:1584:  N:GEXP::GAPDH:2597:  \
# ACC
# TCGA-OR-A5J1               0.069210             0.271446
# TCGA-OR-A5J2               0.067473             0.124547
# TCGA-OR-A5J3               0.073612             0.517511
# TCGA-OR-A5J5               0.050444             0.517602
# TCGA-OR-A5J6               0.134250             0.205643
# ...                             ...                  ...
# TCGA-OU-A5PI               0.047709             0.262458
# TCGA-PA-A5YG               0.121575             0.260933
# TCGA-PK-A5H9               0.154079             0.128061
# TCGA-PK-A5HA               0.097960             0.265716
# TCGA-PK-A5HB               0.022907             0.296656
#
#               N:GEXP::CYP21A2:1589:  N:GEXP::SPARC:6678:  ...  \
# ACC                                                       ...
# TCGA-OR-A5J1               0.371883             0.174878  ...
# TCGA-OR-A5J2               0.069197             0.296471  ...
# TCGA-OR-A5J3               0.150909             0.216615  ...
# TCGA-OR-A5J5               0.161661             0.153389  ...
# TCGA-OR-A5J6               0.264677             0.188601  ...
# ...                             ...                  ...  ...
# TCGA-OU-A5PI               0.165398             0.166029  ...
# TCGA-PA-A5YG               0.050201             0.155501  ...
# TCGA-PK-A5H9               0.097222             0.127728  ...
# TCGA-PK-A5HA               0.031797             0.145794  ...
# TCGA-PK-A5HB               0.031970             0.280075  ...
#
#               N:GEXP::GIYD2:79008:  N:GEXP::PTEN:5728:  N:GEXP::RAI1:10743:  \
# ACC
# TCGA-OR-A5J1              0.383710            0.437921             0.273614
# TCGA-OR-A5J2              0.199557            0.801059             0.519574
# TCGA-OR-A5J3              0.330156            0.457597             0.319972
# TCGA-OR-A5J5              0.598797            0.594756             0.263458
# TCGA-OR-A5J6              0.239386            0.379522             0.175646
# ...                            ...                 ...                  ...
# TCGA-OU-A5PI              0.285021            0.678550             0.283459
# TCGA-PA-A5YG              0.298897            0.497146             0.200530
# TCGA-PK-A5H9              0.179038            0.536367             0.236177
# TCGA-PK-A5HA              0.381383            0.554218             0.173639
# TCGA-PK-A5HB              0.166651            0.512094             0.240366
#
#               N:GEXP::UBN1:29855:  N:GEXP::C11orf48:79081:  \
# ACC
# TCGA-OR-A5J1             0.289425                 0.329941
# TCGA-OR-A5J2             0.602508                 0.087694
# TCGA-OR-A5J3             0.502014                 0.105077
# TCGA-OR-A5J5             0.310759                 0.212401
# TCGA-OR-A5J6             0.319661                 0.242717
# ...                           ...                      ...
# TCGA-OU-A5PI             0.430122                 0.077505
# TCGA-PA-A5YG             0.390781                 0.084921
# TCGA-PK-A5H9             0.475641                 0.138133
# TCGA-PK-A5HA             0.408338                 0.097719
# TCGA-PK-A5HB             0.591903                 0.078481
#
#               N:GEXP::UFD1L:7353:  N:GEXP::PLEKHM2:23207:  \
# ACC
# TCGA-OR-A5J1             0.485494                0.336939
# TCGA-OR-A5J2             0.284785                0.452931
# TCGA-OR-A5J3             0.529800                0.327084
# TCGA-OR-A5J5             0.639652                0.384261
# TCGA-OR-A5J6             0.346819                0.381485
# ...                           ...                     ...
# TCGA-OU-A5PI             0.452298                0.263590
# TCGA-PA-A5YG             0.284863                0.397265
# TCGA-PK-A5H9             0.315688                0.439615
# TCGA-PK-A5HA             0.253849                0.405793
# TCGA-PK-A5HB             0.545150                0.580323
#
#               N:GEXP::ATAD3A:55210:  N:GEXP::PLK2:10769:  N:GEXP::TIAL1:7073:
# ACC
# TCGA-OR-A5J1               0.257602             0.135156             0.446658
# TCGA-OR-A5J2               0.127337             0.218202             0.682711
# TCGA-OR-A5J3               0.319157             0.318746             0.402380
# TCGA-OR-A5J5               0.273733             0.171211             0.544215
# TCGA-OR-A5J6               0.348131             0.119495             0.334425
# ...                             ...                  ...                  ...
# TCGA-OU-A5PI               0.120820             0.209939             0.579909
# TCGA-PA-A5YG               0.159433             0.203813             0.338320
# TCGA-PK-A5H9               0.178551             0.132488             0.388901
# TCGA-PK-A5HA               0.161382             0.149632             0.528024
# TCGA-PK-A5HB               0.608983             0.257644             0.505188
#
# [76 rows x 5001 columns]

# %%
dec_pths = sorted(glob.glob('i_o/box_whisk/ACC_fit_on.ACC_decoded*.tsv'))

# %%
len(dec_pths)
# Out:
# 8

# %%
trn_tst_splts = 50
fig_stack = pd.DataFrame()
for pth in dec_pths:
    config = pth.split('_')[-5]+'_'+pth.split('_')[-4]
    
    dec = pd.read_csv(pth, sep = '\t', index_col = 0)

    print('Starting a quality of embedding F1 object generation run')
    # Need to track the loss plots off the back-end

    F1_output = []
    for r in list(range(0, trn_tst_splts)):
        
        X = dec.iloc[:, 1:]
        y = dec.iloc[:, 0]
        X_train, X_test, y_train, y_test = train_test_split(
                X, y,
                    test_size=0.33,
                        )
        clf = RandomForestClassifier()
        clf.fit(X_train, y_train)

        F1_scr = f1_score(y_test, clf.predict(X_test), average='weighted')
        F1_output.append(F1_scr)

    loop_frame = pd.DataFrame(F1_output, columns = ['F1s'])
    loop_frame.insert(0, 'train_config', config)
    fig_stack = pd.concat([fig_stack, loop_frame], axis = 0)
    # break
print('Learning curve object generated, send to plot function')
# Out:
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Starting a quality of embedding F1 object generation run
# Learning curve object generated, send to plot function

# %%
fig_stack
# Out:
#           train_config       F1s
# 0   dim.100_epochs.160  0.765943
# 1   dim.100_epochs.160  0.596614
# 2   dim.100_epochs.160  0.754309
# 3   dim.100_epochs.160  0.732906
# 4   dim.100_epochs.160  0.683916
# 5   dim.100_epochs.160  0.842780
# 6   dim.100_epochs.160  0.722775
# 7   dim.100_epochs.160  0.657875
# 8   dim.100_epochs.160  0.719091
# 9   dim.100_epochs.160  0.676282
# 10  dim.100_epochs.160  0.680682
# 11  dim.100_epochs.160  0.585487
# 12  dim.100_epochs.160  0.469428
# 13  dim.100_epochs.160  0.803271
# 14  dim.100_epochs.160  0.732742
# 15  dim.100_epochs.160  0.806319
# 16  dim.100_epochs.160  0.638208
# 17  dim.100_epochs.160  0.546154
# 18  dim.100_epochs.160  0.597762
# 19  dim.100_epochs.160  0.772436
# 20  dim.100_epochs.160  0.800399
# 21  dim.100_epochs.160  0.509591
# 22  dim.100_epochs.160  0.692308
# 23  dim.100_epochs.160  0.687587
# 24  dim.100_epochs.160  0.690089
# 25  dim.100_epochs.160  0.777423
# 26  dim.100_epochs.160  0.655204
# 27  dim.100_epochs.160  0.699915
# 28  dim.100_epochs.160  0.748751
# 29  dim.100_epochs.160  0.668956
# 30  dim.100_epochs.160  0.798205
# 31  dim.100_epochs.160  0.641330
# 32  dim.100_epochs.160  0.666721
# 33  dim.100_epochs.160  0.848620
# 34  dim.100_epochs.160  0.873122
# 35  dim.100_epochs.160  0.814652
# 36  dim.100_epochs.160  0.726607
# 37  dim.100_epochs.160  0.813650
# 38  dim.100_epochs.160  0.814173
# 39  dim.100_epochs.160  0.672563
# 40  dim.100_epochs.160  0.574908
# 41  dim.100_epochs.160  0.767110
# 42  dim.100_epochs.160  0.800296
# 43  dim.100_epochs.160  0.723964
# 44  dim.100_epochs.160  0.555556
# 45  dim.100_epochs.160  0.680473
# 46  dim.100_epochs.160  0.569913
# 47  dim.100_epochs.160  0.679071
# 48  dim.100_epochs.160  0.814729
# 49  dim.100_epochs.160  0.775856

# %%
fig_stack.shape # 50 train, test splits by eight epoch / latent dim combos
# Out:
# (400, 2)

# %%
fig_stack.head(1)
# Out:
#          train_config       F1s
# 0  dim.100_epochs.160  0.807692

# %%
inpt_frame.head(1)
# Out:
#     train_config       F1s
# 0  MAD_5k_within  0.829767

# %%
full_stack = pd.concat(
    [inpt_frame, fig_stack], axis = 0)

# %%
sns.color_palette("hls", 10)[2]
# Out:
# (0.7247999999999999, 0.86, 0.33999999999999997)

# %%
pal = sns.color_palette()

# %%
print(pal)
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765), (1.0, 0.4980392156862745, 0.054901960784313725), (0.17254901960784313, 0.6274509803921569, 0.17254901960784313), (0.8392156862745098, 0.15294117647058825, 0.1568627450980392), (0.5803921568627451, 0.403921568627451, 0.7411764705882353), (0.5490196078431373, 0.33725490196078434, 0.29411764705882354), (0.8901960784313725, 0.4666666666666667, 0.7607843137254902), (0.4980392156862745, 0.4980392156862745, 0.4980392156862745), (0.7372549019607844, 0.7411764705882353, 0.13333333333333333), (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
sns.palplot(sns.color_palette("hls", 10)[2])

# %%
sns.palplot(sns.color_palette("hls", 10)[4])

# %%
sns.palplot(sns.color_palette("hls", 10)[6])

# %%
full_stack
# Out:
#          train_config       F1s
# 0       MAD_5k_within  0.829767
# 1       MAD_5k_within  0.616202
# 2       MAD_5k_within  0.702092
# 3       MAD_5k_within  0.604167
# 4       MAD_5k_within  0.647964
# ..                ...       ...
# 45  dim.10_epochs.700  0.798149
# 46  dim.10_epochs.700  0.728438
# 47  dim.10_epochs.700  0.639652
# 48  dim.10_epochs.700  0.526826
# 49  dim.10_epochs.700  0.588103
#
# [450 rows x 2 columns]

# %%
full_stack.train_config.unique()
# Out:
# array(['MAD_5k_within', 'dim.100_epochs.160', 'dim.100_epochs.320',
#        'dim.100_epochs.500', 'dim.100_epochs.700', 'dim.10_epochs.160',
#        'dim.10_epochs.320', 'dim.10_epochs.500', 'dim.10_epochs.700'],
#       dtype=object)

# %%
sns.color_palette("hls", 10)[6]
# Out:
# (0.33999999999999997, 0.5167999999999995, 0.86)

# %%
from matplotlib import rcParams

# %%
inpt_frame.F1s.mean()
# Out:
# 0.71763847344257

# %%
my_pal = {'MAD_5k_within': sns.color_palette("hls", 10)[6],
          'dim.100_epochs.160': sns.color_palette("hls", 10)[4],
          'dim.100_epochs.320': sns.color_palette("hls", 10)[4],
          'dim.100_epochs.500': sns.color_palette("hls", 10)[4],
          'dim.100_epochs.700': sns.color_palette("hls", 10)[4],
          'dim.10_epochs.160': sns.color_palette("hls", 10)[4],
          'dim.10_epochs.320': sns.color_palette("hls", 10)[4],
          'dim.10_epochs.500': sns.color_palette("hls", 10)[4],
          'dim.10_epochs.700': sns.color_palette("hls", 10)[4]}
figure(figsize=(8, 4), dpi=150)
ax = sns.boxplot(full_stack, x='train_config', y='F1s',
           palette = my_pal)
ax.set_xticklabels(ax.get_xticklabels(),rotation=-55,
                   ha='left',
                   rotation_mode='anchor'
                  )
rcParams['xtick.major.pad']='.01'
# ax2 = ax.twinx()
plt.plot(.5, .25, color = 'white')
plt.plot([-.5,8.5], [inpt_frame.F1s.mean(),
                 inpt_frame.F1s.mean()], linestyle='dashed',
        color = sns.color_palette("hls", 10)[6])

plt.suptitle('ACC input vs. decoded')
plt.title('50 train-test splits per feature set',
         fontsize = 10)
plt.annotate('Input\nto VAE', (-.0,.25),
             # fontsize = 15,
             ha = 'center',
            color = sns.color_palette("hls", 10)[6])          # blue
plt.annotate('Decoded', (.2,.1), fontsize = 15) 
plt.savefig('i_o/box_whisk/in_dec_figures/ACC_dim10-100.png', dpi = 150,
           bbox_inches = 'tight')

# %%
ls
# Out:
# DAG_smpl_effct_repo.drawio           figure_five.ipynb
# DAG_smpl_effct_repo.jpg              figure_five_v2.ipynb
# PDF.ipynb                            i_o/
# augmented_policy_cloning.jpg         learning_curve_schematic.drawio
# augmented_policy_cloning.svg         learning_curve_schematic.drawio.png
# box_and_whiskers.ipynb               learning_curve_schematic_v2.drawio
# c_latent_sampling.ipynb              learning_curve_schematic_v2.jpg
# data_aug_deepmind.jpg                shuffle.ipynb
# data_aug_deepmind.svg

# %%
pwd
# Out:
# '/Users/karlberb/Documents/work/sample_count/synthetic_TCGA_data_gen/g_learning_curves'

# %%
# Input and decoded overlay plot
    # Goal: get a good feature set / model set / training protocol
    # Dialed-in quality of embedding plot, run with loss plots *inset plot search
    
# To Inkscape loss plot    
    
plt_v=0 # Version 0 in the figure_five

re_samp = 5 # use file name
trn_tst_splts = 5

figure(figsize=(len(org.index), 8), dpi=150)
# plt.scatter(.01, .99, color = 'white')

x_tck_lst = [] # only need once, done in raw section
cohort_list = [] # only need once, done in raw section

# Original GEXP start
original_ave_means = []
for idx_pos, idx in enumerate(org.index):

    x = idx_pos-.04
    org_ave_mean = [] # for raw, need for deco
    for rs in list(range(0,re_samp)): # use to step through the columns

        adder = .15
        x = x+adder
        plt.errorbar(
            x,
            org.loc[idx, 'mean'+str(rs)],
            yerr=org.loc[idx, 'std'+str(rs)], capsize = 2,
            color = '#90D5EC')
        org_ave_mean.append(org.loc[idx, 'mean'+str(rs)])
    original_ave_means.append(mean(org_ave_mean))
    x_points = [x-.5-.09, x]
    y_points = [mean(org_ave_mean), mean(org_ave_mean)]
    plt.plot(x_points, y_points, linestyle='dashed', color = 'blue') # blue is raw
# end orig gexp
    
    x_tck_lst.append(idx_pos+.5) # only need once, send to end
    cohort_list.append(idx.split('_')[0]) # only need once, send to end
print('orig done')


for idx_pos, idx in enumerate(dec.index): # decoded is green

    x = idx_pos+.04
    dec_ave_mean = []
    for rs in list(range(0,re_samp)): # use to step through the columns

        adder = .15
        x = x+adder
        plt.errorbar(
            x,
            dec.loc[idx, 'mean'+str(rs)],
            yerr=dec.loc[idx, 'std'+str(rs)], capsize = 2,
            color = '#abf7b1')
        dec_ave_mean.append(dec.loc[idx, 'mean'+str(rs)])
        
    x_points = [x-.5-.09, x]
    y_points = [mean(dec_ave_mean), mean(dec_ave_mean)]
    plt.plot(x_points, y_points, linestyle='dashed', color = 'green') # decoded
    
    if original_ave_means[idx_pos] > mean(dec_ave_mean):
        plt.bar(x, height = original_ave_means[idx_pos]-mean(dec_ave_mean),
                width = -.7,
                bottom = mean(dec_ave_mean),
                align = 'edge', color = '#d8f9ff')
        

    if original_ave_means[idx_pos] < mean(dec_ave_mean):
        plt.bar(x, height = original_ave_means[idx_pos]-mean(dec_ave_mean),
                width = -.7,
                bottom = mean(dec_ave_mean),
                align = 'edge', color = '#e8f3db')
    # break
plt.xticks(x_tck_lst, labels = cohort_list, rotation = 45, fontsize = 16) 
plt.suptitle(
    'Raw vs decoded samples, random forest classifier, cohorts n = 25, 5k MAD feats from 17k intersection genes',
    fontsize = 19, y= .96)
plt.title('5 resamplings per cohort at 100% sampling rate, 5'+
          ' train-test splits per resampling, error is standard deviation within each resampling',
         fontsize = 16)
plt.ylabel('F1 score', fontsize = 19)
legend_x, legend_y = -.0, 1.06
y_off = .035

plt.plot((legend_x, legend_x+.5), (legend_y, legend_y),
         linestyle='dashed', color = 'blue') # original
plt.plot((legend_x, legend_x+.5), (legend_y-y_off, legend_y-y_off),
         linestyle='dashed', color = 'green') # decoded

center = .010
plt.annotate('Original', (legend_x+.6,legend_y-center), fontsize = 15)          # blue
plt.annotate('Decoded', (legend_x+.6, legend_y-y_off-center), fontsize = 15) # green

plt.savefig('i_o/figure_five/overlay_repro'+str(plt_v)+'.png',
            dpi = 150, bbox_inches = 'tight')
